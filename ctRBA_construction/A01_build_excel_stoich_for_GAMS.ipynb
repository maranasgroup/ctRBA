# %%
#import necessary packages

import pandas as pd
import cobra
from collections import OrderedDict
from copy import deepcopy
import os
import re as re

from custom_functions_scRBA import *

# %% [markdown]
# #### Specifics of files/conventions used in building this model
# ##### hopefully allows all the editing to take place on a single line in future

# %%
#define default in and out locations
def_in = "input_base"
def_out = "model_base"

#input files
sbml_file = '/'+def_in+'/iCTH669_for_RBA.sbml'                         #stoichiometric network file
prot_st_file = '/'+def_in+'/PROTEIN_stoich_curation_ctherm.xlsx'       #protein information file
aa_map_file = '/'+def_in+'/PROTEIN_amino_acid_map_ctherm.txt'          #amino acid weight map file
dummy_pr_file = '/'+def_in+'/PROTEIN_dummy_prot_calc_ctherm.xlsx'      #dummy protein file
enzy_st_file = '/'+def_in+'/ENZYME_stoich_curation_ctherm.xlsx'        #enzyme stoichiometry file
rna_st_file = '/'+def_in+'/RNA_stoich_ctherm.xlsx'                     #rRNA stoichiometry file
rib_comp_file = '/'+def_in+'/RIBOSOME_composition_ctherm.xlsx'         #ribosome composition file
biomass_file = '/'+def_in+'/BIOMASS_RBA_ctherm.xlsx'                   #biomass composition file
cell_av_conc_file = '/'+def_in+'/av_cellulosome_estimate.xlsx'
cell_cb_conc_file = '/'+def_in+'/cb_cellulosome_estimate.xlsx'
exchange_tag = 'RXN-EXCH_'                                            #string tag used to mark exchange reactions
dummy_length = 276                                                #length of dummy proteins

#output file(s) for the cellulosome
cellulosome_memb_file = '/'+def_out+'/RBA_rxns_prosyn_cell.txt'
cellulosome_waste_file = '/'+def_out+'/RBA_rxns_prowaste_cell.txt'
cell_av_conc_gams_file = '/'+def_out+'/prot_flux_cell_exp_av.txt'
cell_cb_conc_gams_file = '/'+def_out+'/prot_flux_cell_exp_cb.txt'

# %%
sbml_file
# Out:
# '/input_base/iCTH669_for_RBA.sbml'

# %% [markdown]
# #### Load data

# %%
#get the current working directory, this way I don't have to specify filepath all the time
curr_dir = os.getcwd()

# Metabolic model (COBRApy json)
model = cobra.io.read_sbml_model(curr_dir+sbml_file)

# Read protein data including ID, gene name, uniprot ID, location, cofactors (like ions), molecular weight, sequence and status
df_pro = pd.read_excel(curr_dir+prot_st_file)
df_pro.index = df_pro.id.to_list()
df_aamap = pd.read_csv(curr_dir+aa_map_file, sep='\t')
df_aamap.index = df_aamap.aa_abbv.to_list()

# Dummy protein
df_aa_dummy = pd.read_excel(curr_dir+dummy_pr_file)
df_aa_dummy.index = df_aa_dummy.aa_abbv.to_list()
dummy_medianL = int(round(df_aa_dummy.loc['A', 'Unnamed: 5'], 0))
# Add 1e-5 g/mmol to prevent number round lost of protein MW
dummy_MW = round(df_aa_dummy.loc['C', 'Unnamed: 5'], 5) + 1e-5

# Enzyme stoichiometry
df_enz = pd.read_excel(curr_dir+enzy_st_file)

# RNA stoichiometry
df_rnas = pd.read_excel(curr_dir+rna_st_file)
df_rnas.index = df_rnas.RNAid.to_list()

# Ribosome
df_ribo = pd.read_excel(curr_dir+rib_comp_file)

#not sure what this does, 
#df_ribo = df_ribo[df_ribo.paralog.isnull()]

# Biomass
df_biom = pd.read_excel(curr_dir+biomass_file, sheet_name='RBABioRxns')

#read avicel cellulosome file
av_cell_conc = pd.read_excel(curr_dir+cell_av_conc_file)

#set identifiers to the dataframe index
av_cell_conc = av_cell_conc.set_index('identifier')

#read avicel cellulosome file
cb_cell_conc = pd.read_excel(curr_dir+cell_cb_conc_file)

#set identifiers to the dataframe index
cb_cell_conc = cb_cell_conc.set_index('identifier')

# %%
model
# Out:
# <Model iCTH669 at 0x319736680>

# %% [markdown]
# #### if marked as a cellulosome protein, add it to a list of cellulosome proteins, these will be allowed to have protein waste reactions

# %%
#create a list of cellulosomal protein synthesis reactions
cellulosome_membs = list()

#create a list of cellulosomal protein waste reactions
cellulosome_wastes = list()

#create a list for a gams-readable file for C therm synthesis of the cellulosome
av_conc_strings = list()
cb_conc_strings = list()

for prot_id in df_pro.index:

  if re.search(r'cellulosome', str(df_pro.loc[prot_id,'status'])):

    #build the protein synthesis string
    syn_string = "\'PROSYN-"+prot_id+"\'"
    waste_string = "\'PROWASTE-"+prot_id+"\'"
    av_conc_string = "\'PROSYN-"+prot_id+"\'\t"+str(av_cell_conc.loc[prot_id,'estimated molar abundance (mmol/gDCW)'])
    cb_conc_string = "\'PROSYN-"+prot_id+"\'\t"+str(cb_cell_conc.loc[prot_id,'estimated molar abundance (mmol/gDCW)'])

    #for debugging, comment out if unused
    #print(conc_string)

    cellulosome_membs.append(syn_string)
    cellulosome_wastes.append(waste_string)
    av_conc_strings.append(av_conc_string)
    cb_conc_strings.append(cb_conc_string)

#add forward slashes
cellulosome_membs = ['/'] + cellulosome_membs + ['/']
cellulosome_wastes = ['/'] + cellulosome_wastes + ['/']
av_conc_strings = ['/'] + av_conc_strings + ['/']
cb_conc_strings = ['/'] + cb_conc_strings + ['/']

# %%
#write the cellulosome protein file
#with open(curr_dir+cellulosome_memb_file, 'w') as f:
#    f.write('\n'.join(cellulosome_membs))

# %%
#write the cellulosome protein file
with open(curr_dir+cellulosome_waste_file, 'w') as f:
    f.write('\n'.join(cellulosome_wastes))

# %%
#write the cellulosome protein file
#with open(curr_dir+cell_av_conc_gams_file, 'w') as f:
#    f.write('\n'.join(av_conc_strings))

# %%
#write the cellulosome protein file
#with open(curr_dir+cell_cb_conc_gams_file, 'w') as f:
#    f.write('\n'.join(cb_conc_strings))

# %%
#get the list of rRNAs from the rna stoichiometry file
rnas = df_rnas.RNAid.to_list()

rnas
# Out:
# ['rrna23s', 'rrna5s', 'rrna16s']

# %% [markdown]
# #### Assemble reactions

# %%
df_enz
# Out:
#                              id      rxn_src        enz  \
# 0            RXN-13PPDH_FWD-BDH       13PPDH        BDH
# 1      RXN-13PPDH_FWD-gbsB_1798       13PPDH  gbsB_1798
# 2      RXN-13PPDH_FWD-gbsB_1827       13PPDH  gbsB_1827
# 3         RXN-2D3DGLNR_FWD-kduD     2D3DGLNR       kduD
# 4         RXN-2D3DGLNR_REV-kduD     2D3DGLNR       kduD
# ...                         ...          ...        ...
# 1736  RXN-Zn2divalent_FWD-SPONT  Zn2divalent      SPONT
# 1737     RXN-Zn2metal_FWD-SPONT     Zn2metal      SPONT
# 1738       RXN-ZNabc_FWD-znuABC        ZNabc     znuABC
# 1739       RXN-ADCS_FWD-UNKNOWN         ADCS    UNKNOWN
# 1740       RXN-ADCS_REV-UNKNOWN         ADCS    UNKNOWN
#
#                                                  gpr  \
# 0                                       Clo1313_2130
# 1                                       Clo1313_1798
# 2                                       Clo1313_1827
# 3                                       Clo1313_0815
# 4                                       Clo1313_0815
# ...                                              ...
# 1736                                           SPONT
# 1737                                           SPONT
# 1738  Clo1313_1688 and Clo1313_1689 and Clo1313_1690
# 1739                                         UNKNOWN
# 1740                                         UNKNOWN
#
#                                     protein_stoich subunit_comments  \
# 0                                   Clo1313_2130:1
# 1                                   Clo1313_1798:1
# 2                                   Clo1313_1827:1
# 3                                   Clo1313_0815:1
# 4                                   Clo1313_0815:1
# ...                                            ...              ...
# 1736                                      zeroCost              NaN
# 1737                                      zeroCost
# 1738  Clo1313_1688:1,Clo1313_1689:1,Clo1313_1690:1
# 1739                                      zeroCost              NaN
# 1740                                      zeroCost              NaN
#
#                     status  MW (g/mmol)
# 0       protStoichAsgnAuto     43.33800
# 1       protStoichAsgnAuto     96.85200
# 2       protStoichAsgnAuto     42.48978
# 3       protStoichAsgnAuto     27.91363
# 4       protStoichAsgnAuto     27.91363
# ...                    ...          ...
# 1736  protStoichAsgnManual     89.80625
# 1737    protStoichAsgnAuto      0.00000
# 1738    protStoichAsgnAuto      0.00000
# 1739                   NaN          NaN
# 1740                   NaN          NaN
#
# [1741 rows x 8 columns]

# %%
df_enz.iloc[591]['id']
# Out:
# 'RXN-EXCH_cell5_e_FWD-SPONT'

# %%
for i in df_enz.index:
    
    rxn_id = df_enz.id[i]

    _,rxn_base_id,rxn_dir,enz_id = extract_details_from_rxnid(rxn_id)
    
    if rxn_id[:len(exchange_tag)] == exchange_tag:

        print("id: ",rxn_id,"\tbase id: ",rxn_base_id,"\tdir: ",rxn_dir,"\tenz_id: ",enz_id)

    if rxn_id[:len(exchange_tag)] == exchange_tag:

        print("id: ",rxn_id,"\tbase id: ",rxn_base_id,"\tdir: ",rxn_dir,"\tenz_id: ",enz_id)
# Out:
# id:  RXN-EXCH_2mbtoh_e_FWD-SPONT 	base id:  EXCH_2mbtoh_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_2mbtoh_e_FWD-SPONT 	base id:  EXCH_2mbtoh_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_4crsol_e_FWD-SPONT 	base id:  EXCH_4crsol_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_4crsol_e_FWD-SPONT 	base id:  EXCH_4crsol_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_5oxpro_e_FWD-SPONT 	base id:  EXCH_5oxpro_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_5oxpro_e_FWD-SPONT 	base id:  EXCH_5oxpro_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_ac_e_FWD-SPONT 	base id:  EXCH_ac_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_ac_e_FWD-SPONT 	base id:  EXCH_ac_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_ade_e_FWD-SPONT 	base id:  EXCH_ade_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_ade_e_FWD-SPONT 	base id:  EXCH_ade_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_adocbl_e_FWD-SPONT 	base id:  EXCH_adocbl_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_adocbl_e_FWD-SPONT 	base id:  EXCH_adocbl_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_ala__L_e_FWD-SPONT 	base id:  EXCH_ala__L_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_ala__L_e_FWD-SPONT 	base id:  EXCH_ala__L_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_amob_e_FWD-SPONT 	base id:  EXCH_amob_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_amob_e_FWD-SPONT 	base id:  EXCH_amob_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_arg__L_e_FWD-SPONT 	base id:  EXCH_arg__L_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_arg__L_e_FWD-SPONT 	base id:  EXCH_arg__L_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_asn__L_e_FWD-SPONT 	base id:  EXCH_asn__L_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_asn__L_e_FWD-SPONT 	base id:  EXCH_asn__L_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_asp__L_e_FWD-SPONT 	base id:  EXCH_asp__L_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_asp__L_e_FWD-SPONT 	base id:  EXCH_asp__L_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_btd_M_e_FWD-SPONT 	base id:  EXCH_btd_M_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_btd_M_e_FWD-SPONT 	base id:  EXCH_btd_M_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_btd_RR_e_FWD-SPONT 	base id:  EXCH_btd_RR_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_btd_RR_e_FWD-SPONT 	base id:  EXCH_btd_RR_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_ca2_e_FWD-SPONT 	base id:  EXCH_ca2_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_ca2_e_FWD-SPONT 	base id:  EXCH_ca2_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_ca2_e_REV-SPONT 	base id:  EXCH_ca2_e 	dir:  REV 	enz_id:  SPONT
# id:  RXN-EXCH_ca2_e_REV-SPONT 	base id:  EXCH_ca2_e 	dir:  REV 	enz_id:  SPONT
# id:  RXN-EXCH_cell3_e_FWD-SPONT 	base id:  EXCH_cell3_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_cell3_e_FWD-SPONT 	base id:  EXCH_cell3_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_cell3_e_REV-SBP_cellx 	base id:  EXCH_cell3_e 	dir:  REV 	enz_id:  SBP_cellx
# id:  RXN-EXCH_cell3_e_REV-SBP_cellx 	base id:  EXCH_cell3_e 	dir:  REV 	enz_id:  SBP_cellx
# id:  RXN-EXCH_cell4_e_FWD-SPONT 	base id:  EXCH_cell4_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_cell4_e_FWD-SPONT 	base id:  EXCH_cell4_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_cell4_e_REV-SBP_cellx 	base id:  EXCH_cell4_e 	dir:  REV 	enz_id:  SBP_cellx
# id:  RXN-EXCH_cell4_e_REV-SBP_cellx 	base id:  EXCH_cell4_e 	dir:  REV 	enz_id:  SBP_cellx
# id:  RXN-EXCH_cell5_e_FWD-SPONT 	base id:  EXCH_cell5_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_cell5_e_FWD-SPONT 	base id:  EXCH_cell5_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_cell5_e_REV-SBP_cellx 	base id:  EXCH_cell5_e 	dir:  REV 	enz_id:  SBP_cellx
# id:  RXN-EXCH_cell5_e_REV-SBP_cellx 	base id:  EXCH_cell5_e 	dir:  REV 	enz_id:  SBP_cellx
# id:  RXN-EXCH_cell6_e_FWD-SPONT 	base id:  EXCH_cell6_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_cell6_e_FWD-SPONT 	base id:  EXCH_cell6_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_cell6_e_REV-SBP_cellx 	base id:  EXCH_cell6_e 	dir:  REV 	enz_id:  SBP_cellx
# id:  RXN-EXCH_cell6_e_REV-SBP_cellx 	base id:  EXCH_cell6_e 	dir:  REV 	enz_id:  SBP_cellx
# id:  RXN-EXCH_cellb_e_FWD-SPONT 	base id:  EXCH_cellb_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_cellb_e_FWD-SPONT 	base id:  EXCH_cellb_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_cellb_e_REV-SBP_cellx 	base id:  EXCH_cellb_e 	dir:  REV 	enz_id:  SBP_cellx
# id:  RXN-EXCH_cellb_e_REV-SBP_cellx 	base id:  EXCH_cellb_e 	dir:  REV 	enz_id:  SBP_cellx
# id:  RXN-EXCH_cit_e_FWD-SPONT 	base id:  EXCH_cit_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_cit_e_FWD-SPONT 	base id:  EXCH_cit_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_co2_e_FWD-SPONT 	base id:  EXCH_co2_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_co2_e_FWD-SPONT 	base id:  EXCH_co2_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_cys__L_e_FWD-SPONT 	base id:  EXCH_cys__L_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_cys__L_e_FWD-SPONT 	base id:  EXCH_cys__L_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_cytd_e_FWD-SPONT 	base id:  EXCH_cytd_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_cytd_e_FWD-SPONT 	base id:  EXCH_cytd_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_etoh_e_FWD-SPONT 	base id:  EXCH_etoh_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_etoh_e_FWD-SPONT 	base id:  EXCH_etoh_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_fe3_e_FWD-SPONT 	base id:  EXCH_fe3_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_fe3_e_FWD-SPONT 	base id:  EXCH_fe3_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_fe3_e_REV-SPONT 	base id:  EXCH_fe3_e 	dir:  REV 	enz_id:  SPONT
# id:  RXN-EXCH_fe3_e_REV-SPONT 	base id:  EXCH_fe3_e 	dir:  REV 	enz_id:  SPONT
# id:  RXN-EXCH_zn2_e_FWD-SPONT 	base id:  EXCH_zn2_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_zn2_e_FWD-SPONT 	base id:  EXCH_zn2_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_zn2_e_REV-SPONT 	base id:  EXCH_zn2_e 	dir:  REV 	enz_id:  SPONT
# id:  RXN-EXCH_zn2_e_REV-SPONT 	base id:  EXCH_zn2_e 	dir:  REV 	enz_id:  SPONT
# id:  RXN-EXCH_mn2_e_FWD-SPONT 	base id:  EXCH_mn2_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_mn2_e_FWD-SPONT 	base id:  EXCH_mn2_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_mn2_e_REV-SPONT 	base id:  EXCH_mn2_e 	dir:  REV 	enz_id:  SPONT
# id:  RXN-EXCH_mn2_e_REV-SPONT 	base id:  EXCH_mn2_e 	dir:  REV 	enz_id:  SPONT
# id:  RXN-EXCH_cobalt2_e_FWD-SPONT 	base id:  EXCH_cobalt2_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_cobalt2_e_FWD-SPONT 	base id:  EXCH_cobalt2_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_cobalt2_e_REV-SPONT 	base id:  EXCH_cobalt2_e 	dir:  REV 	enz_id:  SPONT
# id:  RXN-EXCH_cobalt2_e_REV-SPONT 	base id:  EXCH_cobalt2_e 	dir:  REV 	enz_id:  SPONT
# id:  RXN-EXCH_for_e_FWD-SPONT 	base id:  EXCH_for_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_for_e_FWD-SPONT 	base id:  EXCH_for_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_fru_e_FWD-SPONT 	base id:  EXCH_fru_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_fru_e_FWD-SPONT 	base id:  EXCH_fru_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_fuc__L_e_FWD-SPONT 	base id:  EXCH_fuc__L_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_fuc__L_e_FWD-SPONT 	base id:  EXCH_fuc__L_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_fum_e_FWD-SPONT 	base id:  EXCH_fum_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_fum_e_FWD-SPONT 	base id:  EXCH_fum_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_g1p_e_FWD-SPONT 	base id:  EXCH_g1p_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_g1p_e_FWD-SPONT 	base id:  EXCH_g1p_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_glc__D_e_FWD-SPONT 	base id:  EXCH_glc__D_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_glc__D_e_FWD-SPONT 	base id:  EXCH_glc__D_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_glc__D_e_REV-SBP_cellx 	base id:  EXCH_glc__D_e 	dir:  REV 	enz_id:  SBP_cellx
# id:  RXN-EXCH_glc__D_e_REV-SBP_cellx 	base id:  EXCH_glc__D_e 	dir:  REV 	enz_id:  SBP_cellx
# id:  RXN-EXCH_glceq_e_FWD-SPONT 	base id:  EXCH_glceq_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_glceq_e_FWD-SPONT 	base id:  EXCH_glceq_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_gln__L_e_FWD-SPONT 	base id:  EXCH_gln__L_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_gln__L_e_FWD-SPONT 	base id:  EXCH_gln__L_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_glu__L_e_FWD-SPONT 	base id:  EXCH_glu__L_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_glu__L_e_FWD-SPONT 	base id:  EXCH_glu__L_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_gly_e_FWD-SPONT 	base id:  EXCH_gly_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_gly_e_FWD-SPONT 	base id:  EXCH_gly_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_glycogen_c_FWD-SPONT 	base id:  EXCH_glycogen_c 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_glycogen_c_FWD-SPONT 	base id:  EXCH_glycogen_c 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_gsn_e_FWD-SPONT 	base id:  EXCH_gsn_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_gsn_e_FWD-SPONT 	base id:  EXCH_gsn_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_h_e_FWD-SPONT 	base id:  EXCH_h_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_h_e_FWD-SPONT 	base id:  EXCH_h_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_h_e_REV-SPONT 	base id:  EXCH_h_e 	dir:  REV 	enz_id:  SPONT
# id:  RXN-EXCH_h_e_REV-SPONT 	base id:  EXCH_h_e 	dir:  REV 	enz_id:  SPONT
# id:  RXN-EXCH_h2_e_FWD-SPONT 	base id:  EXCH_h2_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_h2_e_FWD-SPONT 	base id:  EXCH_h2_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_h2o_e_FWD-SPONT 	base id:  EXCH_h2o_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_h2o_e_FWD-SPONT 	base id:  EXCH_h2o_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_h2o_e_REV-SPONT 	base id:  EXCH_h2o_e 	dir:  REV 	enz_id:  SPONT
# id:  RXN-EXCH_h2o_e_REV-SPONT 	base id:  EXCH_h2o_e 	dir:  REV 	enz_id:  SPONT
# id:  RXN-EXCH_h2s_e_FWD-SPONT 	base id:  EXCH_h2s_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_h2s_e_FWD-SPONT 	base id:  EXCH_h2s_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_his__L_e_FWD-SPONT 	base id:  EXCH_his__L_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_his__L_e_FWD-SPONT 	base id:  EXCH_his__L_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_ibutoh_e_FWD-SPONT 	base id:  EXCH_ibutoh_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_ibutoh_e_FWD-SPONT 	base id:  EXCH_ibutoh_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_ile__L_e_FWD-SPONT 	base id:  EXCH_ile__L_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_ile__L_e_FWD-SPONT 	base id:  EXCH_ile__L_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_k_e_FWD-SPONT 	base id:  EXCH_k_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_k_e_FWD-SPONT 	base id:  EXCH_k_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_k_e_REV-SPONT 	base id:  EXCH_k_e 	dir:  REV 	enz_id:  SPONT
# id:  RXN-EXCH_k_e_REV-SPONT 	base id:  EXCH_k_e 	dir:  REV 	enz_id:  SPONT
# id:  RXN-EXCH_lac__L_e_FWD-SPONT 	base id:  EXCH_lac__L_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_lac__L_e_FWD-SPONT 	base id:  EXCH_lac__L_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_leu__L_e_FWD-SPONT 	base id:  EXCH_leu__L_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_leu__L_e_FWD-SPONT 	base id:  EXCH_leu__L_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_lys__L_e_FWD-SPONT 	base id:  EXCH_lys__L_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_lys__L_e_FWD-SPONT 	base id:  EXCH_lys__L_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_mal__L_e_FWD-SPONT 	base id:  EXCH_mal__L_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_mal__L_e_FWD-SPONT 	base id:  EXCH_mal__L_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_met__D_e_FWD-SPONT 	base id:  EXCH_met__D_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_met__D_e_FWD-SPONT 	base id:  EXCH_met__D_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_met__L_e_FWD-SPONT 	base id:  EXCH_met__L_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_met__L_e_FWD-SPONT 	base id:  EXCH_met__L_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_mg2_e_FWD-SPONT 	base id:  EXCH_mg2_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_mg2_e_FWD-SPONT 	base id:  EXCH_mg2_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_mg2_e_REV-SPONT 	base id:  EXCH_mg2_e 	dir:  REV 	enz_id:  SPONT
# id:  RXN-EXCH_mg2_e_REV-SPONT 	base id:  EXCH_mg2_e 	dir:  REV 	enz_id:  SPONT
# id:  RXN-EXCH_na1_e_FWD-SPONT 	base id:  EXCH_na1_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_na1_e_FWD-SPONT 	base id:  EXCH_na1_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_na1_e_REV-SPONT 	base id:  EXCH_na1_e 	dir:  REV 	enz_id:  SPONT
# id:  RXN-EXCH_na1_e_REV-SPONT 	base id:  EXCH_na1_e 	dir:  REV 	enz_id:  SPONT
# id:  RXN-EXCH_nac_e_FWD-SPONT 	base id:  EXCH_nac_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_nac_e_FWD-SPONT 	base id:  EXCH_nac_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_nh4_e_FWD-SPONT 	base id:  EXCH_nh4_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_nh4_e_FWD-SPONT 	base id:  EXCH_nh4_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_nh4_e_REV-SPONT 	base id:  EXCH_nh4_e 	dir:  REV 	enz_id:  SPONT
# id:  RXN-EXCH_nh4_e_REV-SPONT 	base id:  EXCH_nh4_e 	dir:  REV 	enz_id:  SPONT
# id:  RXN-EXCH_ni2_e_FWD-SPONT 	base id:  EXCH_ni2_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_ni2_e_FWD-SPONT 	base id:  EXCH_ni2_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_ni2_e_REV-SPONT 	base id:  EXCH_ni2_e 	dir:  REV 	enz_id:  SPONT
# id:  RXN-EXCH_ni2_e_REV-SPONT 	base id:  EXCH_ni2_e 	dir:  REV 	enz_id:  SPONT
# id:  RXN-EXCH_o2_e_FWD-SPONT 	base id:  EXCH_o2_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_o2_e_FWD-SPONT 	base id:  EXCH_o2_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_o2_e_REV-SPONT 	base id:  EXCH_o2_e 	dir:  REV 	enz_id:  SPONT
# id:  RXN-EXCH_o2_e_REV-SPONT 	base id:  EXCH_o2_e 	dir:  REV 	enz_id:  SPONT
# id:  RXN-EXCH_akg_e_REV-SPONT 	base id:  EXCH_akg_e 	dir:  REV 	enz_id:  SPONT
# id:  RXN-EXCH_akg_e_REV-SPONT 	base id:  EXCH_akg_e 	dir:  REV 	enz_id:  SPONT
# id:  RXN-EXCH_akg_e_FWD-SPONT 	base id:  EXCH_akg_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_akg_e_FWD-SPONT 	base id:  EXCH_akg_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_phe__L_e_FWD-SPONT 	base id:  EXCH_phe__L_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_phe__L_e_FWD-SPONT 	base id:  EXCH_phe__L_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_pi_e_FWD-SPONT 	base id:  EXCH_pi_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_pi_e_FWD-SPONT 	base id:  EXCH_pi_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_pi_e_REV-SPONT 	base id:  EXCH_pi_e 	dir:  REV 	enz_id:  SPONT
# id:  RXN-EXCH_pi_e_REV-SPONT 	base id:  EXCH_pi_e 	dir:  REV 	enz_id:  SPONT
# id:  RXN-EXCH_pnto__R_e_FWD-SPONT 	base id:  EXCH_pnto__R_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_pnto__R_e_FWD-SPONT 	base id:  EXCH_pnto__R_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_ppoh_e_FWD-SPONT 	base id:  EXCH_ppoh_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_ppoh_e_FWD-SPONT 	base id:  EXCH_ppoh_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_pro__L_e_FWD-SPONT 	base id:  EXCH_pro__L_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_pro__L_e_FWD-SPONT 	base id:  EXCH_pro__L_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_ptrc_e_FWD-SPONT 	base id:  EXCH_ptrc_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_ptrc_e_FWD-SPONT 	base id:  EXCH_ptrc_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_pyr_e_FWD-SPONT 	base id:  EXCH_pyr_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_pyr_e_FWD-SPONT 	base id:  EXCH_pyr_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_rib__D_e_FWD-SPONT 	base id:  EXCH_rib__D_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_rib__D_e_FWD-SPONT 	base id:  EXCH_rib__D_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_ribflv_e_FWD-SPONT 	base id:  EXCH_ribflv_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_ribflv_e_FWD-SPONT 	base id:  EXCH_ribflv_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_sbt__D_e_FWD-SPONT 	base id:  EXCH_sbt__D_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_sbt__D_e_FWD-SPONT 	base id:  EXCH_sbt__D_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_ser__L_e_FWD-SPONT 	base id:  EXCH_ser__L_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_ser__L_e_FWD-SPONT 	base id:  EXCH_ser__L_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_so4_e_FWD-SPONT 	base id:  EXCH_so4_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_so4_e_FWD-SPONT 	base id:  EXCH_so4_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_so4_e_REV-SPONT 	base id:  EXCH_so4_e 	dir:  REV 	enz_id:  SPONT
# id:  RXN-EXCH_so4_e_REV-SPONT 	base id:  EXCH_so4_e 	dir:  REV 	enz_id:  SPONT
# id:  RXN-EXCH_spmd_e_FWD-SPONT 	base id:  EXCH_spmd_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_spmd_e_FWD-SPONT 	base id:  EXCH_spmd_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_succ_e_FWD-SPONT 	base id:  EXCH_succ_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_succ_e_FWD-SPONT 	base id:  EXCH_succ_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_thm_e_FWD-SPONT 	base id:  EXCH_thm_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_thm_e_FWD-SPONT 	base id:  EXCH_thm_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_thr__L_e_FWD-SPONT 	base id:  EXCH_thr__L_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_thr__L_e_FWD-SPONT 	base id:  EXCH_thr__L_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_thymd_e_FWD-SPONT 	base id:  EXCH_thymd_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_thymd_e_FWD-SPONT 	base id:  EXCH_thymd_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_trp__L_e_FWD-SPONT 	base id:  EXCH_trp__L_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_trp__L_e_FWD-SPONT 	base id:  EXCH_trp__L_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_tyr__L_e_FWD-SPONT 	base id:  EXCH_tyr__L_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_tyr__L_e_FWD-SPONT 	base id:  EXCH_tyr__L_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_urea_e_FWD-SPONT 	base id:  EXCH_urea_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_urea_e_FWD-SPONT 	base id:  EXCH_urea_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_uri_e_FWD-SPONT 	base id:  EXCH_uri_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_uri_e_FWD-SPONT 	base id:  EXCH_uri_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_val__L_e_FWD-SPONT 	base id:  EXCH_val__L_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_val__L_e_FWD-SPONT 	base id:  EXCH_val__L_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_xylt_e_FWD-SPONT 	base id:  EXCH_xylt_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_xylt_e_FWD-SPONT 	base id:  EXCH_xylt_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_co_e_FWD-SPONT 	base id:  EXCH_co_e 	dir:  FWD 	enz_id:  SPONT
# id:  RXN-EXCH_co_e_FWD-SPONT 	base id:  EXCH_co_e 	dir:  FWD 	enz_id:  SPONT

# %%
df_eqn = pd.DataFrame(columns=['id', 'type', 'coupling_type', 'coupling_species', 'reaction'])
#c = df_eqn.shape[0] - 1
c = -1

"""
### Metabolic network reaction
# Exchange reactions
for rxn in model.reactions:
    if rxn.id[:len(exchange_tag)] == exchange_tag:
        
        met = [i for i in rxn.metabolites.keys()][0]
        
        c += 1
        new_id = 'RXN-' + rxn.id + '_FWD-SPONT'
        df_eqn.loc[c, 'id'] = new_id
        df_eqn.loc[c, 'type'] = 'metabolic'
        df_eqn.loc[c, 'reaction'] = 'MET-' + met.id + ' -->'
        
        c += 1
        new_id = 'RXN-' + rxn.id + '_REV-SPONT'
        df_eqn.loc[c, 'id'] = new_id
        df_eqn.loc[c, 'type'] = 'metabolic'
        df_eqn.loc[c, 'reaction'] = '-->' + 'MET-' + met.id
        
"""


# Reactions that are not exchange reactions
for i in df_enz.index:
    rxn_id = df_enz.id[i]
    _,rxn_base_id,rxn_dir,enz_id = extract_details_from_rxnid(rxn_id)
    
    """
    #updated to the exchange reaction tag I use
    if rxn_base_id[:len(exchange_tag)] == exchange_tag:
        continue
    """

    #skip empty items
    if rxn_base_id[:len(exchange_tag)] == exchange_tag:
        continue

    #from wheaton, for debugging, comment out when no bug problems in this section
    print(rxn_base_id,"\n")
    
    c += 1
    rxn_base = model.reactions.get_by_id(rxn_base_id)
    
    met_dict = metabolites_dict_from_reaction_equation_RBA(rxn_base.reaction)
    met_dict = {k:v for k,v in met_dict.items() if k != ''}
    met_dict = {'MET-' + k:v for k,v in met_dict.items()}
    
    if rxn_dir == 'REV':

        #if reverse, flip coefficients, I think
        met_dict = {k:-v for k,v in met_dict.items()}

    elif rxn_dir == 'FWD':

        #if forward, keep copefficients same, I think
        None

    else:
        
        #some error handling seems to exist
        print("Unknown ID that indicate reaction direction, only accepting 'FWD' and 'REV'")
    
    if enz_id not in ['SPONT', 'UNKNOWN']:
        df_eqn.loc[c, 'coupling_type'] = 'rxn_enz'
        df_eqn.loc[c, 'coupling_species'] = enz_id
    
    df_eqn.loc[c, 'id'] = rxn_id
    df_eqn.loc[c, 'type'] = 'metabolic'
    df_eqn.loc[c, 'reaction'] = build_reaction_equation_from_metabolites_dict_RBA(met_dict, arrow='-->')
    
### Enzyme synthesis network reaction
enz_stoich = OrderedDict()
for i in df_enz.index:
    enz_stoich[df_enz.enz[i]] = df_enz.protein_stoich[i]

c = df_eqn.shape[0] - 1

#looks like here, the protein building reactions are starting
for enz_id,prot_str in enz_stoich.items():

    if prot_str == 'zeroCost':
        continue

    #added by wheaton for debugging, comment out when not in use
    if enz_id == "pupG":
        
        print("row #: ",c,"\tenz_id: ",enz_id,"\tprot_str: ",prot_str)
    
    c += 1
    prot_str = prot_str.split(',')
    coeffs = OrderedDict({'PRO-' + i.split(':')[0]:-int(i.split(':')[1]) for i in prot_str})
    coeffs['ENZ-' + enz_id] = 1
    
    df_eqn.loc[c, 'id'] = 'ENZSYN-' + enz_id
    df_eqn.loc[c, 'type'] = 'enzyme'
    df_eqn.loc[c, 'reaction'] = build_reaction_equation_from_metabolites_dict_RBA(coeffs, arrow='-->')

#these ENZLOAD equations also need to have their MW listed in the enz_mw_g_per_mmol file
#initialize an enzload sting
enzload_str = ""

for i in df_enz.index:
    
    if df_enz.protein_stoich[i] == 'zeroCost':
        continue
        
    c += 1
    coeffs = OrderedDict()
    coeffs['ENZ-' + df_enz.enz[i]] = -1

    enzload_id = 'ENZLOAD-' + df_enz.id[i][4:]

    #for debugging, comment out if unused
    print("i: ",i,"\tenzload_id: ", enzload_id)
    
    df_eqn.loc[c, 'id'] = enzload_id
    df_eqn.loc[c, 'type'] = 'enzymeRxnLoad'
    df_eqn.loc[c, 'reaction'] = build_reaction_equation_from_metabolites_dict_RBA(coeffs, arrow='-->')

    #get the associated mw
    enz_mw = getattr(df_enz,"MW (g/mmol)")[i]

    new_line = enzload_id + "\t" + str(enz_mw) + "\n"
    enzload_str = enzload_str + new_line

#write the file resulting from enzload_str
with open('./'+def_out+'/enz_mw_g_per_mmol.txt', 'w') as f:
    f.write(enzload_str)
    
### Ribosome
c = df_eqn.shape[0] - 1

#for debugging, comment out when not using
#print(rnas)

for rna in rnas:
    
    c += 1
    rna_stoich = OrderedDict({i:0 for i in ['MET-'+rna, 'MET-atp_c', 'MET-ctp_c',
                                            'MET-gtp_c', 'MET-utp_c', 'MET-ppi_c']})
    rna_stoich['RIBO-'+rna] = 1
    rna_stoich['MET-atp_c'] = -int(df_rnas.A[rna])
    rna_stoich['MET-ctp_c'] = -int(df_rnas.C[rna])
    rna_stoich['MET-gtp_c'] = -int(df_rnas.G[rna])
    rna_stoich['MET-utp_c'] = -int(df_rnas.U[rna])
    rna_stoich['MET-ppi_c'] = int(df_rnas.loc[rna, ['A','C','G','U']].sum())
    rna_stoich['BIO-rrna'] = df_rnas.loc[rna, 'MW (g/mmol)']

    #for debugging, comment out if not used
    #print(rna_stoich)
    
    df_eqn.loc[c, 'id'] = 'RIBOSYN-' + rna
    df_eqn.loc[c, 'type'] = 'ribosome'
    df_eqn.loc[c, 'reaction'] = build_reaction_equation_from_metabolites_dict_RBA(rna_stoich, arrow='-->')
    
c += 1
ribo_stoich = OrderedDict()

for i in df_ribo.index:
    if df_ribo.id[i] in rnas:
        ribo_stoich['RIBO-' + df_ribo.id[i]] = -1
    else:
        ribo_stoich['PRO-' + df_ribo.id[i]] = -1
df_eqn.loc[c, 'id'] = 'RIBOSYN-ribo'
df_eqn.loc[c, 'type'] = 'ribosome'
df_eqn.loc[c, 'reaction'] = build_reaction_equation_from_metabolites_dict_RBA(ribo_stoich, arrow='-->')
# Out:
# 13PPDH
#
# 13PPDH
#
# 13PPDH
#
# 2D3DGLNR
#
# 2D3DGLNR
#
# 2DHPFALDL
#
# 2HBO
#
# 2HBO
#
# 34DHOXPEGOX
#
# 34DHOXPEGOX
#
# 3HAD100
#
# 3HAD100
#
# 3HAD120
#
# 3HAD120
#
# 3HAD140
#
# 3HAD140
#
# 3HAD160
#
# 3HAD160
#
# 3HAD180
#
# 3HAD180
#
# 3HAD40_1
#
# 3HAD40_1
#
# 3HAD60
#
# 3HAD60
#
# 3HAD80
#
# 3HAD80
#
# 3MOPDC
#
# 3OACOAS
#
# 3OAR100
#
# 3OAR100
#
# 3OAR100
#
# 3OAR100
#
# 3OAR120
#
# 3OAR120
#
# 3OAR120
#
# 3OAR120
#
# 3OAR140
#
# 3OAR140
#
# 3OAR140
#
# 3OAR140
#
# 3OAR160
#
# 3OAR160
#
# 3OAR160
#
# 3OAR160
#
# 3OAR18B
#
# 3OAR18B
#
# 3OAR18B
#
# 3OAR18B
#
# 3OAR40
#
# 3OAR40
#
# 3OAR40
#
# 3OAR40
#
# 3OAR60
#
# 3OAR60
#
# 3OAR60
#
# 3OAR60
#
# 3OAR80
#
# 3OAR80
#
# 3OAR80
#
# 3OAR80
#
# 3OAS100
#
# 3OAS100
#
# 3OAS100
#
# 3OAS100
#
# 3OAS100
#
# 3OAS120
#
# 3OAS120
#
# 3OAS120
#
# 3OAS120
#
# 3OAS120
#
# 3OAS140
#
# 3OAS140
#
# 3OAS140
#
# 3OAS140
#
# 3OAS140
#
# 3OAS160
#
# 3OAS160
#
# 3OAS160
#
# 3OAS160
#
# 3OAS160
#
# 3OAS60
#
# 3OAS80
#
# 3OAS80
#
# 3OAS80
#
# 3OAS80
#
# 3OAS80
#
# 3SALATA
#
# 3SALATA
#
# 3SALATA
#
# 3SALATA
#
# 4crsolt
#
# 4crsolt
#
# 4HTHRS
#
# 4MOPDC
#
# 5FLURAPRT2
#
# 6TINS5MPOR
#
# 6TXAN5MPAML
#
# AABHH
#
# AACPS3MBUT
#
# AACPS3MBUT
#
# AACPS3MCR
#
# AACPS3MCR
#
# AATC
#
# AATC
#
# AATC
#
# AATC
#
# ABGPT
#
# ABGPT
#
# ACabc
#
# ACALD
#
# ACALDy
#
# ACAS_2ahbut
#
# ACAS_2ahbut
#
# ACBIPGT
#
# ACBIPGT
#
# ACCOAC
#
# ACGK
#
# ACGNMCT
#
# ACGS
#
# ACKr
#
# ACKr
#
# ACLDC
#
# ACLS
#
# ACLS
#
# ACNAM9PL
#
# ACNAM9PL
#
# ACNMCT
#
# ACNPLYS
#
# ACNPLYS
#
# ACOATA
#
# ACOATA
#
# ACOATA
#
# ACONT
#
# ACONT
#
# ACOTA
#
# ACOTA
#
# ACPS1
#
# ACS2
#
# ACt
#
# ACt2
#
# ADA
#
# ADA
#
# ADAPAT
#
# ADCL
#
# ADCPS1
#
# ADCPS2
#
# ADEabc
#
# ADEabc
#
# ADK1
#
# ADK1
#
# ADK2
#
# ADK2
#
# ADMDC
#
# ADOCBIK
#
# ADOCBIK2
#
# ADOCBLabc
#
# ADOCBLS
#
# ADPCOAL
#
# ADPCOAL
#
# ADPCOAL
#
# ADPCOAL
#
# ADPRDP
#
# ADPT
#
# ADPT
#
# ADPT2
#
# ADPT2
#
# ADPT2
#
# ADPT2
#
# ADSK
#
# ADSL1r
#
# ADSL1r
#
# ADSL2r
#
# ADSL2r
#
# AGDC
#
# AGMT
#
# AGPR
#
# AGPR
#
# AGT
#
# AGT
#
# AHCi
#
# AHDTPHL
#
# AHEXASE3
#
# AHSERL2
#
# AHSERL2
#
# AHSERL4
#
# AHSERL4
#
# AHSERL4
#
# AHSERL4
#
# AHSL
#
# AHSL
#
# AICART
#
# AICART
#
# AIRC3
#
# AKP1
#
# ALAALAr
#
# ALAALAr
#
# ALAR
#
# ALAR
#
# ALAt
#
# ALAt
#
# ALATRS
#
# ALCD22xi
#
# ALCD22xi2
#
# ALCD23xi
#
# ALCD23xi2
#
# ALCD23yi
#
# ALCD2x
#
# ALCD2y
#
# ALCD3MBOH
#
# ALCD3x
#
# ALDD1
#
# ALDD1
#
# ALDD20x
#
# ALDD20x
#
# ALDD22x
#
# ALDD2x
#
# ALDH
#
# ALLAS
#
# ALLAS
#
# AMAOTr
#
# AMAOTr
#
# AMPTASECG
#
# AMPTASECG
#
# AMUAAH
#
# AMUAAH
#
# AMUAAH
#
# AMUAAH
#
# AMUAAH
#
# AMUAAH
#
# AMUAAH
#
# AMUAAH
#
# AMUAAH
#
# AMUAAH
#
# ANPRT
#
# ANS
#
# AOXPBDC
#
# AOXSr
#
# AOXSr
#
# AOXSr2
#
# APCPT
#
# APCS
#
# APCS
#
# APL
#
# APL
#
# APNPT
#
# APNTPM
#
# APNTPM
#
# APPAT
#
# APRAUR
#
# ARGabc
#
# ARGDC
#
# ARGDC
#
# ARGSL
#
# ARGSL
#
# ARGSS
#
# ARGSS
#
# ARGTRS
#
# AROH
#
# ASAD
#
# ASAD
#
# ASAHL
#
# ASNabc
#
# ASNabc
#
# ASNabc
#
# ASNabc
#
# ASNS1
#
# ASNS1
#
# ASNS2
#
# ASNS2
#
# ASNTRAT
#
# ASNTRAT
#
# ASNTRS
#
# ASP1DC
#
# ASPabc
#
# ASPabc
#
# ASPCT
#
# ASPK
#
# ASPO2
#
# ASPO2y
#
# ASPTA
#
# ASPTA
#
# ASPTRS
#
# ASPTRS
#
# ATAS
#
# ATAS
#
# ATPM
#
# ATPM
#
# ATPM
#
# ATPM
#
# ATPM
#
# ATPPRT
#
# BACCL
#
# BC13FAS
#
# BC13FAS
#
# BC17FAS
#
# BC17FAS
#
# BDG2HCGHD
#
# BDG2HCGHD
#
# BDG2HCGHD
#
# BDG2HCGHD
#
# BDG2HCGHD
#
# BDG2HCGHD
#
# BGGHL
#
# BGGHL
#
# BHPR
#
# BHPR
#
# BHPR
#
# BHPR
#
# BHPR
#
# BHPR
#
# BIF
#
# BIF
#
# BIF
#
# BIF
#
# BPNT
#
# BTCOARx
#
# BTDD_M
#
# BTDD_M
#
# BTDD_RR
#
# BTDD_RR
#
# BTDt_M
#
# BTDt_M
#
# BTDt_RR
#
# BTDt_RR
#
# BTS6
#
# BTS6
#
# Ca2CaZn
#
# Ca2divalent
#
# Ca2metal
#
# CAT
#
# CAt7r
#
# CAt7r
#
# CBIAT
#
# CBPS
#
# CBPS
#
# CDGPT
#
# CDGS
#
# CDGSOT
#
# CDGSOT
#
# CDGUNPD
#
# CDGUNPD
#
# CDP4D6DGLCRx
#
# CDP4D6DGLCRx2
#
# CDPGLC46DH
#
# CDPMEK
#
# CEL2abc
#
# CEL2abc
#
# CEL2abc
#
# CEL2abc
#
# CEL3abc
#
# CEL3abc
#
# CEL3abc
#
# CEL3abc
#
# CEL4abc
#
# CEL4abc
#
# CEL4abc
#
# CEL4abc
#
# CEL5abc
#
# CEL5abc
#
# CEL5abc
#
# CEL5abc
#
# CEL6abc
#
# CEL6abc
#
# CEL6abc
#
# CEL6abc
#
# CEPA
#
# CEPA2
#
# CEPA3
#
# CEPA4
#
# CEPA5
#
# CGGH
#
# CGGH
#
# CGGH
#
# CHORM
#
# CHORM
#
# CHRS
#
# CITCIb
#
# CITCIb
#
# CITMS
#
# CITMS
#
# CITt2
#
# CITt2
#
# CLS
#
# CLS2
#
# CMIPDCOAL
#
# CMIPDCOAL
#
# CMIPDCOAL
#
# CMIPDCOAL
#
# CMS
#
# Co2CoZn
#
# CO2t
#
# CO2t
#
# COabc
#
# COabc
#
# COt
#
# COt
#
# CPCOAL
#
# CPCOAL
#
# CPCOAL
#
# CPCOAL
#
# CPHL
#
# CPPPGO2
#
# CPPPGO2
#
# CPPPGO2
#
# CPPPGO2
#
# CPPPGO2
#
# CPPPGO2
#
# CPPPGO2
#
# CPPPGO2
#
# CPPPGO2
#
# CPPPGO2
#
# CPPPGO2
#
# CPPPGO2
#
# CPPPGO2
#
# CPPPGO2
#
# CPPPGO2
#
# CPPPGO2
#
# CPPPGO2
#
# CPPPGO2
#
# CPPPGO2
#
# CPPPGO2
#
# CPPPGO2
#
# CPPPGO2
#
# CS
#
# CS
#
# CS
#
# CS
#
# CTPS1
#
# CTPS2
#
# CYRDAAT
#
# CYS
#
# CYS
#
# CYSDES
#
# CYSDES
#
# CYSOR
#
# CYSOR
#
# CYSS
#
# CYSS
#
# CYSTA
#
# CYSTA
#
# CYSTRS
#
# CYTD
#
# CYTD
#
# CYTDabc
#
# CYTDabc
#
# CYTDK1
#
# CYTDK2
#
# CYTK1
#
# CYTK1
#
# CYTK2
#
# DADK
#
# DAGP
#
# DAGS
#
# DAGS
#
# DAPDC
#
# DAPE
#
# DAPE
#
# DATCY
#
# DATUP
#
# DB4PS
#
# DBTS
#
# DCMPDA
#
# DCTCP
#
# DCTPD
#
# DCTPD2
#
# DCTUP
#
# DCYTD
#
# DCYTD
#
# DGK1
#
# DGTCY
#
# DGTUP
#
# DHAD1
#
# DHAD2
#
# DHDOR
#
# DHDPRx_r
#
# DHDPRx_r
#
# DHDPRx_r
#
# DHDPRx_r
#
# DHFOR
#
# DHFOR2
#
# DHFR
#
# DHFR2i
#
# DHFS
#
# DHNAOT4
#
# DHNPA2r
#
# DHORD_NAD
#
# DHPPDA2
#
# DHPS
#
# DHPS2_1
#
# DHQS
#
# DHR
#
# DHR
#
# DLDLBT
#
# DLMETR
#
# DLMETR
#
# DM_TEST
#
# DMATT
#
# DMPPS
#
# DOLPMT
#
# DOLPMT
#
# DOLPMT
#
# DPCOAK
#
# DPHS
#
# DPHS
#
# DPR
#
# DQDH
#
# DQDH
#
# DRPA
#
# DRPA
#
# DRPA
#
# DTMPK
#
# DTMPK
#
# DTTGY
#
# DTTUP
#
# DURIPP
#
# DURIPP
#
# DURIPP
#
# DURIPP
#
# DURIPP
#
# DURIPP
#
# DUTCP
#
# DUTPDP
#
# DUTUP
#
# DXPS
#
# DXRI
#
# E4PD
#
# EAR100x
#
# EAR100x
#
# EAR120x
#
# EAR120x
#
# EAR140x
#
# EAR140x
#
# EAR40x
#
# EAR40x
#
# EAR60x
#
# EAR60x
#
# EAR80x
#
# EAR80x
#
# ECH
#
# ECH_3hivcoa
#
# ECH_3hivcoa
#
# ECOAH1
#
# ECOAH1
#
# ECOAH2
#
# ECOAH2
#
# ECOAH2c2
#
# ECOAH2c2
#
# ECOAH2c2
#
# ECOAH2c2
#
# ECOAH2c2
#
# ECOAH2c2
#
# ECOAH3
#
# ECOAH3
#
# ECOAH4
#
# ECOAH4
#
# ECOAH5
#
# ECOAH5
#
# ECOAH6
#
# ECOAH6
#
# ECOAH7
#
# ECOAH7
#
# ECOAH9ir
#
# ECOAH9ir
#
# EGMEST
#
# EHGLAT
#
# EHGLAT
#
# EHGLAT
#
# EHGLAT
#
# ENO
#
# ENO
#
# ETOHt
#
# ETOHt
#
# EXCH_2mbtoh_e
#
# EXCH_4crsol_e
#
# EXCH_5oxpro_e
#
# EXCH_ac_e
#
# EXCH_ade_e
#
# EXCH_adocbl_e
#
# EXCH_ala__L_e
#
# EXCH_amob_e
#
# EXCH_arg__L_e
#
# EXCH_asn__L_e
#
# EXCH_asp__L_e
#
# EXCH_btd_M_e
#
# EXCH_btd_RR_e
#
# EXCH_ca2_e
#
# EXCH_ca2_e
#
# EXCH_cell3_e
#
# EXCH_cell3_e
#
# EXCH_cell4_e
#
# EXCH_cell4_e
#
# EXCH_cell5_e
#
# EXCH_cell5_e
#
# EXCH_cell6_e
#
# EXCH_cell6_e
#
# EXCH_cellb_e
#
# EXCH_cellb_e
#
# EXCH_cit_e
#
# EXCH_co2_e
#
# EXCH_cys__L_e
#
# EXCH_cytd_e
#
# EXCH_etoh_e
#
# EXCH_fe3_e
#
# EXCH_fe3_e
#
# EXCH_zn2_e
#
# EXCH_zn2_e
#
# EXCH_mn2_e
#
# EXCH_mn2_e
#
# EXCH_cobalt2_e
#
# EXCH_cobalt2_e
#
# EXCH_for_e
#
# EXCH_fru_e
#
# EXCH_fuc__L_e
#
# EXCH_fum_e
#
# EXCH_g1p_e
#
# EXCH_glc__D_e
#
# EXCH_glc__D_e
#
# EXCH_glceq_e
#
# EXCH_gln__L_e
#
# EXCH_glu__L_e
#
# EXCH_gly_e
#
# EXCH_glycogen_c
#
# EXCH_gsn_e
#
# EXCH_h_e
#
# EXCH_h_e
#
# EXCH_h2_e
#
# EXCH_h2o_e
#
# EXCH_h2o_e
#
# EXCH_h2s_e
#
# EXCH_his__L_e
#
# EXCH_ibutoh_e
#
# EXCH_ile__L_e
#
# EXCH_k_e
#
# EXCH_k_e
#
# EXCH_lac__L_e
#
# EXCH_leu__L_e
#
# EXCH_lys__L_e
#
# EXCH_mal__L_e
#
# EXCH_met__D_e
#
# EXCH_met__L_e
#
# EXCH_mg2_e
#
# EXCH_mg2_e
#
# EXCH_na1_e
#
# EXCH_na1_e
#
# EXCH_nac_e
#
# EXCH_nh4_e
#
# EXCH_nh4_e
#
# EXCH_ni2_e
#
# EXCH_ni2_e
#
# EXCH_o2_e
#
# EXCH_o2_e
#
# EXCH_akg_e
#
# EXCH_akg_e
#
# EXCH_phe__L_e
#
# EXCH_pi_e
#
# EXCH_pi_e
#
# EXCH_pnto__R_e
#
# EXCH_ppoh_e
#
# EXCH_pro__L_e
#
# EXCH_ptrc_e
#
# EXCH_pyr_e
#
# EXCH_rib__D_e
#
# EXCH_ribflv_e
#
# EXCH_sbt__D_e
#
# EXCH_ser__L_e
#
# EXCH_so4_e
#
# EXCH_so4_e
#
# EXCH_spmd_e
#
# EXCH_succ_e
#
# EXCH_thm_e
#
# EXCH_thr__L_e
#
# EXCH_thymd_e
#
# EXCH_trp__L_e
#
# EXCH_tyr__L_e
#
# EXCH_urea_e
#
# EXCH_uri_e
#
# EXCH_val__L_e
#
# EXCH_xylt_e
#
# EXCH_co_e
#
# F1PGT
#
# F6PPT
#
# F6PPT
#
# FACOAL160
#
# FADDP
#
# FADDP
#
# FADRx
#
# FADRx2
#
# FASOD
#
# FASOD
#
# FASOXST
#
# FASOXST
#
# FASOXST
#
# FASOXST
#
# FASOXST
#
# FATPase
#
# FBA
#
# FBA
#
# FBA
#
# FBA
#
# FBA3
#
# FBA3
#
# FCLK
#
# FCLPA
#
# FDH
#
# FE2OR
#
# FE3abc
#
# FGFTh
#
# FMNAT
#
# FNOR
#
# FORabc
#
# FORt
#
# FORt2r
#
# FPGLP
#
# FRDx
#
# FRDx
#
# FRNDPR2r
#
# FRNDPR2r
#
# FRTT
#
# FRTT
#
# FRUabc
#
# FRUabc
#
# FRUabc
#
# FRUabc
#
# FTCL
#
# FTHFLi
#
# FUCabc
#
# FUCabc
#
# FUCabc
#
# FUCabc
#
# FUM
#
# FUM
#
# FUMabc
#
# FUMt
#
# FUMt2
#
# G1PACT
#
# G1PCTYT
#
# G1SAT
#
# G1SAT
#
# G3PCT
#
# G3PD1ir
#
# G3PD2
#
# G5SADs
#
# G5SADs
#
# G5SD
#
# GALAS
#
# GALAS
#
# GALU
#
# GALU
#
# GAPD
#
# GAPD
#
# GARFT
#
# GCALDD
#
# GDAGS
#
# GDAGS
#
# GDAGS2
#
# GDAGS2
#
# GF6PTA
#
# GFUCS
#
# GFUCS
#
# GGT
#
# GGT
#
# GGT
#
# GGT
#
# GGT
#
# GGT
#
# GGT
#
# GGT
#
# GGT
#
# GGT
#
# GGT
#
# GGT
#
# GHMT2r
#
# GHMT2r
#
# GK1
#
# GK1
#
# GLAS
#
# GLAS
#
# GLCabc
#
# GLCabc
#
# GLCabc
#
# GLCabc
#
# GLCEQ3
#
# GLCEQ4
#
# GLCEQ5
#
# GLCEQ6
#
# GLCP
#
# GLCS1
#
# GLCS1
#
# GLGC
#
# GLGC
#
# GLGC
#
# GLNabc
#
# GLNabc
#
# GLNS
#
# GLNS
#
# GLNS
#
# GLNS
#
# GLNSP2
#
# GLNSP2
#
# GLNSP2
#
# GLNSP2
#
# GLNTRAT
#
# GLNTRAT
#
# GLNTRS
#
# GLU5K
#
# GLUabc
#
# GLUabc
#
# GLUDy
#
# GLUDy
#
# GLUN
#
# GLUN
#
# GLUN
#
# GLUN
#
# GLUN
#
# GLUN
#
# GLUN
#
# GLUN
#
# GLUN
#
# GLUN
#
# GLUN
#
# GLUN
#
# GLUN
#
# GLUN
#
# GLUN
#
# GLUN
#
# GLUPRT
#
# GLUR
#
# GLUR
#
# GLUTAS
#
# GLUTAS
#
# GLUTRR
#
# GLUTRS
#
# GLYALDDr
#
# GLYALDDr
#
# GLYAT
#
# GLYAT
#
# GLYCDH
#
# GLYCK2
#
# GLYCL
#
# GLYCL
#
# GLYCL
#
# GLYCLTDx
#
# GLYCLTDx
#
# GLYHMT
#
# GLYHMT
#
# GLYK
#
# GLYPT
#
# GLYt
#
# GLYt
#
# GLYTA
#
# GLYTA
#
# GLYTAS
#
# GLYTAS
#
# GLYTRS
#
# GMAND
#
# GMAND
#
# GMPS
#
# GMPS2
#
# GPAR
#
# GPAR
#
# GRTT
#
# GSNabc
#
# GSNabc
#
# GTPCI
#
# GTPCII2
#
# GTPDPDP
#
# GTPDPK
#
# GUAD_1
#
# H2ASE_syn
#
# H2ASE_syn2
#
# H2Ot
#
# H2Ot
#
# AKGt
#
# AKGt
#
# SUCCt
#
# SUCCt
#
# H2St1
#
# H2td
#
# H2td
#
# HACPMCACT
#
# HACPMCACT
#
# HADCPCOAHL
#
# HADCPCOAHL
#
# HAMR
#
# HAMR
#
# HBCO
#
# HBCO
#
# HBCO
#
# HBCO
#
# HCBPHAL
#
# HCBPHAL
#
# HCBPHAL
#
# HDCDH
#
# HDCDH
#
# HDCDH
#
# HDCDH
#
# HDCDH
#
# HDCDH
#
# HDCDH
#
# HDCDH
#
# HDHL
#
# HEPDPS
#
# HEPDPS
#
# HEX1
#
# HEX7
#
# HIALOR
#
# HIALOR
#
# HICHCOAL
#
# HICHCOAL
#
# HICHCOAL
#
# HICHCOAL
#
# HICHCOAL
#
# HICHCOAL
#
# HISabc
#
# HISabc
#
# HISDC
#
# HISOR
#
# HISTP
#
# HISTRS
#
# HMBDPO
#
# HMBPAL
#
# HMBPAL
#
# HMBPAL
#
# HMBS
#
# HMNOR
#
# HMNOR
#
# HOGL
#
# HOGL
#
# HOGL
#
# HOGL
#
# HOMBPAL
#
# HOMBPAL
#
# HOMBPAL
#
# HPHBHL
#
# HPHBHL
#
# HPS
#
# HPS
#
# HPS
#
# HPS
#
# HPYRRx
#
# HPYRRx
#
# HSDH
#
# HSDH
#
# HSDxi
#
# HSDxi
#
# HSERTA
#
# HSERTA
#
# HSK
#
# HSK
#
# HSOR
#
# HSST
#
# HSTPT
#
# HSTPT
#
# HTHRPDH
#
# HTHRPDH
#
# HXPRT
#
# HXPRT
#
# I2FE2SS
#
# I2FE2SS2
#
# I2FE2ST
#
# I4FE4SR
#
# I4FE4ST
#
# IBUTCOARx
#
# IBUTCOARy
#
# IBUTOHt
#
# IBUTOHt
#
# ICDHyr
#
# ICOR
#
# ICYSDS
#
# IDS2
#
# IG3PS
#
# IGPDH
#
# IGPS
#
# ILEt
#
# ILEt
#
# ILETA
#
# ILETA
#
# ILETRS
#
# IMACTD
#
# IMPC
#
# IMPC
#
# IMPD
#
# IMPD
#
# IPDOR
#
# IPDPS
#
# IPDPTA
#
# IPDPTA
#
# IPMD
#
# IPMD
#
# IPOCOAL
#
# IPOCOAL
#
# IPOCOAL
#
# IPOCOAL
#
# IPOHCOAL
#
# IPOHCOAL
#
# IPOHCOAL
#
# IPOHCOAL
#
# IPPMIa
#
# IPPMIa
#
# IPPMIb
#
# IPPMIb
#
# IPPS
#
# IPPS
#
# ITCY
#
# K2metal
#
# K2MgK
#
# K2nh4K
#
# K3tr
#
# K3tr
#
# KARA1
#
# KARI
#
# KARI
#
# KARI_23dhmb
#
# KARI_23dhmp
#
# KARI_23dhmp
#
# KARI_3hmoa
#
# KARI_3hmoa
#
# KAS14
#
# KAS14
#
# KAS14
#
# KAS14
#
# KHK
#
# KLCGH
#
# KLCGH
#
# LACLabc
#
# LACt
#
# LACt2r
#
# LACZ
#
# LAS
#
# LAS
#
# LDAPAT
#
# LDAPAT
#
# LDH_L
#
# LDH_L
#
# LDH_L
#
# LDH_L
#
# LEUt
#
# LEUt
#
# LEUTA
#
# LEUTRS
#
# LHOR
#
# LYSabc
#
# LYSDC
#
# LYSDC
#
# LYSTRS
#
# MAGS
#
# MAGS
#
# MALLabc
#
# MALt
#
# MALt2
#
# MAN1PT
#
# MAN1PT
#
# MAN1PT
#
# MCACPR
#
# MCACPR
#
# MCITS
#
# MCLORi
#
# MCLORi
#
# MCMMT
#
# MCMMT
#
# MCOATA
#
# MCS
#
# MCS
#
# MDH
#
# MDH
#
# ME1
#
# ME2
#
# METAT
#
# METDabc
#
# METS
#
# METS
#
# METS
#
# METS
#
# METS
#
# METTRS
#
# Mg2divalent
#
# Mg2metal
#
# Mg2MgK
#
# Mg2MgMn
#
# MG2t
#
# MG2t
#
# MGSA
#
# MHECOAHL
#
# MHECOAHL
#
# MMCD
#
# MMCD
#
# MMCD
#
# MMCD
#
# MMCD
#
# MMCD
#
# MMHL
#
# MMHL
#
# MMOR
#
# MMSDH
#
# Mn2divalent
#
# Mn2metal
#
# Mn2MgMn
#
# MN2t
#
# MOHMT
#
# MPAKI
#
# MPAKI
#
# MS
#
# MTAP
#
# MTAP
#
# MTAP
#
# MTAP
#
# MTAS
#
# MTAS
#
# MTHFC
#
# MTHFC
#
# MTHFD
#
# MTHFD
#
# MTHFO
#
# MTHFO_nadp
#
# MtnA
#
# MtnB
#
# MtnP
#
# MtnP
#
# MTRI
#
# MTRI
#
# NA1abc
#
# NABTNO
#
# NABTNO
#
# NACecf
#
# NACecf
#
# NADK
#
# NADS2
#
# NAMNPP
#
# NAt3
#
# NAt3
#
# NBAH
#
# NDPK1
#
# NDPK1
#
# NDPK10
#
# NDPK2
#
# NDPK2
#
# NDPK3
#
# NDPK3
#
# NDPK4
#
# NDPK5
#
# NDPK6
#
# NDPK7
#
# NDPK8
#
# NDPK9
#
# NDPK9
#
# nh42nh4K
#
# NH4tabc
#
# NHHA
#
# NHHA
#
# NHMSCOAH
#
# NHMSCOAH
#
# NHMSCOAH
#
# NHMSCOAH
#
# NHMSCOAH
#
# NHMSCOAH
#
# Ni2t
#
# Ni2t
#
# NIabc
#
# NICRNS
#
# NMNAT
#
# NMNAT
#
# NMNAT
#
# NMNAT
#
# NMOR
#
# NMOR
#
# NNAT
#
# NNDMBRT
#
# NNDPR
#
# NO2OR
#
# NO2OR
#
# NP1
#
# NP1
#
# NP1
#
# NP1
#
# NP1
#
# NP1
#
# NPH
#
# NPH
#
# NTD1
#
# NTD1
#
# NTD3
#
# NTD5
#
# NTD8
#
# NTP3
#
# NTPH
#
# NTPP1
#
# NTPP1
#
# NTPP10
#
# NTPP11
#
# NTPP2
#
# NTPP2
#
# NTPP3
#
# NTPP3
#
# NTPP4
#
# NTPP4
#
# NTPP5
#
# NTPP5
#
# NTPP6
#
# NTPP6
#
# NTPP7
#
# NTPP7
#
# NTPP8
#
# NTPP8
#
# NTPP9
#
# NTPTP1
#
# NTPTP1
#
# o2t
#
# o2t
#
# OAADC
#
# OAADC
#
# OBFOR
#
# OBFOR
#
# OBFOR
#
# OBTFL
#
# OBTFL
#
# OCBT
#
# OCBT
#
# OCTDPS
#
# OHPBAT
#
# OHPBAT
#
# OMCDC
#
# OMPDC
#
# OOR3
#
# ORNDC
#
# ORNTAC
#
# ORNTAC
#
# ORPT
#
# ORPT
#
# OXSCL
#
# P5CR
#
# PAACOAL
#
# PAACOAL
#
# PAACOAL
#
# PAACOAL
#
# PACCOAL
#
# PACCOAL
#
# PACPT
#
# PACPT
#
# PAL
#
# PANTS
#
# PAPSR
#
# PDGS
#
# PDHam1hi
#
# PDHam1hi
#
# PDX5POi
#
# PDX5PS2
#
# PECGONCOAT
#
# PECGONCOAT
#
# PECGONCOAT
#
# PECGONCOAT
#
# PEPCK_re
#
# PERD
#
# PFK_2
#
# PFK_4
#
# PFK_4
#
# PFK_5
#
# PFK_5
#
# PFK_6
#
# PFK_6
#
# PFK3_ppi
#
# PFK3_ppi
#
# PFL
#
# PFL
#
# PGAMT
#
# PGAMT
#
# PGI
#
# PGI
#
# PGK
#
# PGK2
#
# PGLP
#
# PGLS
#
# PGLYDH
#
# PGM
#
# PGM
#
# PGM
#
# PGM
#
# PGM
#
# PGM
#
# PGMT
#
# PGMT
#
# PHEt
#
# PHEt
#
# PHETA1
#
# PHETA1
#
# PHETA1
#
# PHETA1
#
# PHETA1
#
# PHETA1
#
# PHETA1
#
# PHETA1
#
# PHETRS
#
# PHSD
#
# PINAt
#
# PIt
#
# PIt2
#
# PMANM
#
# PMANM
#
# PMANM
#
# PMANM
#
# PMDPHT
#
# PMDPHT
#
# PMDPHT
#
# PMEACPE
#
# PMEACPE
#
# PMPK
#
# PNP
#
# PNP
#
# PNP
#
# PNP
#
# PNP
#
# PNP
#
# PNTK
#
# PNTOecf
#
# PNTOecf
#
# POR
#
# POR
#
# POR
#
# PP2MO
#
# PP2MO
#
# PP2MO
#
# PP2MO
#
# PP2MO
#
# PP2MO
#
# PPA
#
# PPAKr
#
# PPAKr
#
# PPAna
#
# PPBNGS
#
# PPCDC
#
# PPDHL
#
# PPDK
#
# PPDK
#
# PPDOy
#
# PPDOy
#
# PPGPPDP
#
# PPM
#
# PPM
#
# PPM
#
# PPM
#
# PPM2
#
# PPM2
#
# PPNCL2
#
# PPNCL3
#
# PPND
#
# PPNDH
#
# PPRGL
#
# PPROR
#
# PPROR
#
# PPYRDC
#
# PRAI
#
# PRAI
#
# PRAICL
#
# PRAIS
#
# PRAIS
#
# PRAMPC
#
# PRASCSi
#
# PRASCSi
#
# PRATPP
#
# PRFGS
#
# PRFGS
#
# PRFGS
#
# PRMICI
#
# PRO1x
#
# PROt
#
# PROt
#
# PROTRS
#
# PRPPS
#
# PSAT
#
# PSAT
#
# PSCVT
#
# PSCVT
#
# PSP
#
# PSP
#
# PSP
#
# PSP
#
# PSP
#
# PSP
#
# PSP
#
# PSP
#
# PTA2
#
# PTA2
#
# PTAr
#
# PTAr
#
# PTHPS
#
# PTRCabc
#
# PUNP1
#
# PUNP1
#
# PUNP1
#
# PUNP1
#
# PUNP1
#
# PUNP1
#
# PUNP2
#
# PUNP2
#
# PUNP2
#
# PUNP2
#
# PUNP2
#
# PUNP2
#
# PUNP3
#
# PUNP3
#
# PUNP3
#
# PUNP3
#
# PUNP3
#
# PUNP3
#
# PUNP4
#
# PUNP4
#
# PUNP4
#
# PUNP4
#
# PUNP4
#
# PUNP4
#
# PUNP5
#
# PUNP5
#
# PUNP5
#
# PUNP5
#
# PUNP5
#
# PUNP5
#
# PUNP6
#
# PUNP6
#
# PUNP6
#
# PUNP6
#
# PUNP6
#
# PUNP6
#
# PUNP7
#
# PUNP7
#
# PUNP7
#
# PUNP7
#
# PUNP7
#
# PUNP7
#
# PYLALDOX
#
# PYLALDOX
#
# PYNP1
#
# PYNP1
#
# PYNP2r
#
# PYNP2r
#
# PYRabc
#
# PYRGt
#
# PYRGt
#
# PYRt
#
# PYRt2r
#
# QUINDH
#
# QULNS
#
# QUOR
#
# R00182
#
# R00182
#
# R02135
#
# R02135
#
# R02135
#
# R02135
#
# R03004
#
# R03004
#
# R03036
#
# R03036
#
# R03105
#
# R03472
#
# R03472
#
# R04399
#
# R04399
#
# R04399
#
# R04399
#
# R04399
#
# R04399
#
# R05046
#
# R05602
#
# R05602
#
# R05602
#
# R05602
#
# R05602
#
# R05602
#
# R07459
#
# R07460
#
# R07460
#
# R07461
#
# R09543
#
# R09543
#
# R09977
#
# R10115
#
# R10116
#
# R10116
#
# R10117
#
# R10117
#
# R10118
#
# R10118
#
# R10119
#
# R10120
#
# R10120
#
# R10121
#
# R10121
#
# R10122
#
# R10122
#
# R10246
#
# R10246
#
# R10247
#
# R10712
#
# R11098
#
# R11099
#
# R11633
#
# R11634
#
# R11635
#
# R11636
#
# RBFK
#
# RBFK
#
# RBFSb
#
# RDXR
#
# RDXR
#
# RE0581R
#
# RE0581R
#
# RIBabc
#
# RIBabc
#
# RIBabc
#
# RIBabc
#
# RIBFLVecf
#
# RIBFLVecf
#
# RNDR1n
#
# RNDR2
#
# RNDR3
#
# RNDR4
#
# RNF
#
# RNF
#
# RNMK
#
# RNTR1
#
# RNTR2
#
# RNTR3
#
# RNTR4
#
# RPE
#
# RPE
#
# RPI
#
# RPI
#
# RPYS
#
# RPYS
#
# rxn27289
#
# rxn27289
#
# rxn27289
#
# rxn27289
#
# rxn44628
#
# rxn44628
#
# RZ5PP
#
# RZ5PP
#
# RZ5PP
#
# RZ5PP
#
# SADT
#
# SADT
#
# SALCCM
#
# SALCCM
#
# SALMCCOAMT
#
# SALMCCOAMT
#
# SBTabc
#
# SBTabc
#
# SBTabc
#
# SBTabc
#
# SBTD_D2
#
# SBTD_D2
#
# SBTD_D2
#
# SBTD_D2
#
# SDPTA
#
# SDPTA
#
# SERabc
#
# SERabc
#
# SERAT
#
# SERH
#
# SERH
#
# SERTRS
#
# SERTRS2
#
# SHCHD2
#
# SHCHF
#
# SHCHF
#
# SHOR
#
# SHSL1
#
# SHSL1
#
# SHSL2
#
# SHSL4
#
# SKDH
#
# SKK
#
# SKK
#
# SLCYSS
#
# SLCYSS
#
# SLCYSS
#
# SMLSHL
#
# SMLSHL
#
# SPMDabc
#
# SPMS
#
# SPMS
#
# SPRMS
#
# SPRMS
#
# SPRMS
#
# SPRMS
#
# SULabc
#
# SULabc
#
# SULR_ferr
#
# TBALOR
#
# TDPDRE
#
# TDPDRE
#
# TDPGDH
#
# TDPGDH
#
# TGBPA
#
# THFGLUS
#
# THFOR1
#
# THFOR2
#
# THFOR2
#
# THISAT
#
# THISAT
#
# THMecf
#
# THMecf
#
# THPAT
#
# THRabc
#
# THRabc
#
# THRS
#
# THRTRS
#
# TKT1
#
# TKT1
#
# TKT1
#
# TKT1
#
# TKT2
#
# TKT2
#
# TKT2
#
# TKT2
#
# TMAMT
#
# TMAMT
#
# TMAMT
#
# TMAMT
#
# TMAMT
#
# TMAMT
#
# TMDPK
#
# TMDPP
#
# TMDPP
#
# TMDPPK
#
# TMDS
#
# TMIPDCOAL
#
# TMIPDCOAL
#
# TMIPDCOAL
#
# TMIPDCOAL
#
# TPI
#
# TPI
#
# TRDR
#
# TRDR
#
# TRNAALAUDAT
#
# TRNAATPAT
#
# TRNAATPAT
#
# TRNACCAT
#
# TRNACCAT
#
# TRNACTPAT
#
# TRNACTPAT
#
# TRNACTPAT2
#
# TRNACTPAT2
#
# TRNAGLYUDAT
#
# TRPabc
#
# TRPabc
#
# TRPS2
#
# TRPS2
#
# TRPS3
#
# TRPTRS
#
# TYHMDabc
#
# TYHMDabc
#
# TYRabc
#
# TYRabc
#
# TYRTA
#
# TYRTA
#
# TYRTA
#
# TYRTA
#
# TYRTA
#
# TYRTA
#
# TYRTA
#
# TYRTA
#
# TYRTRS
#
# UAAGDS
#
# UAAGLS2
#
# UACMUOR
#
# UAG2E
#
# UAG2EMA
#
# UAG2EMA
#
# UAG4Ei
#
# UAG4Ei
#
# UAG4Ei
#
# UAG4Ei
#
# UAGCVT
#
# UAGCVT
#
# UAGCVT
#
# UAGDH
#
# UAGDH
#
# UAGP2UAG
#
# UAGPT2
#
# UAGPT3
#
# UAMAGS
#
# UAMAS
#
# UAPGR
#
# UDCP
#
# UDCPDPS
#
# UDCPT
#
# UDPG2DGT
#
# UDPGD
#
# UDPGDC
#
# UDPGP
#
# UDPGP
#
# UDPKAAT
#
# UG6PGT
#
# UGE2
#
# UGE2
#
# UGE2
#
# UGE2
#
# UGLDDS2
#
# UGMDDS
#
# UMPK
#
# UMPK
#
# UPP3MT
#
# UPP3S_1
#
# UPPPHL
#
# UPPRT
#
# UPPRT
#
# UPPRT
#
# UREA
#
# UREAabc
#
# URIabc
#
# URIabc
#
# URIDK2r
#
# URIDK2r
#
# URIK1
#
# URIK2
#
# URIK3
#
# UTCY
#
# UTUP
#
# VALt
#
# VALt
#
# VALTA
#
# VALTA
#
# VALTRS
#
# vATPS
#
# VOR1b
#
# VOR2b
#
# VOR3b
#
# XPPT
#
# XPPT
#
# XYLK
#
# XYLK
#
# XYLTD_D
#
# XYLTt
#
# XYLTt
#
# Zn2CaZn
#
# Zn2CoZn
#
# Zn2divalent
#
# Zn2metal
#
# ZNabc
#
# ADCS
#
# ADCS
#
# i:  0 	enzload_id:  ENZLOAD-13PPDH_FWD-BDH
# i:  1 	enzload_id:  ENZLOAD-13PPDH_FWD-gbsB_1798
# i:  2 	enzload_id:  ENZLOAD-13PPDH_FWD-gbsB_1827
# i:  3 	enzload_id:  ENZLOAD-2D3DGLNR_FWD-kduD
# i:  4 	enzload_id:  ENZLOAD-2D3DGLNR_REV-kduD
# i:  5 	enzload_id:  ENZLOAD-2DHPFALDL_FWD-panB
# i:  6 	enzload_id:  ENZLOAD-2HBO_FWD-lctE
# i:  7 	enzload_id:  ENZLOAD-2HBO_FWD-lctE_1160
# i:  8 	enzload_id:  ENZLOAD-34DHOXPEGOX_FWD-gbsB_1798
# i:  9 	enzload_id:  ENZLOAD-34DHOXPEGOX_REV-gbsB_1798
# i:  10 	enzload_id:  ENZLOAD-3HAD100_FWD-fabZ
# i:  11 	enzload_id:  ENZLOAD-3HAD100_REV-fabZ
# i:  12 	enzload_id:  ENZLOAD-3HAD120_FWD-fabZ
# i:  13 	enzload_id:  ENZLOAD-3HAD120_REV-fabZ
# i:  14 	enzload_id:  ENZLOAD-3HAD140_FWD-fabZ
# i:  15 	enzload_id:  ENZLOAD-3HAD140_REV-fabZ
# i:  16 	enzload_id:  ENZLOAD-3HAD160_FWD-fabZ
# i:  17 	enzload_id:  ENZLOAD-3HAD160_REV-fabZ
# i:  18 	enzload_id:  ENZLOAD-3HAD180_FWD-fabZ
# i:  19 	enzload_id:  ENZLOAD-3HAD180_REV-fabZ
# i:  20 	enzload_id:  ENZLOAD-3HAD40_1_FWD-fabZ
# i:  21 	enzload_id:  ENZLOAD-3HAD40_1_REV-fabZ
# i:  22 	enzload_id:  ENZLOAD-3HAD60_FWD-fabZ
# i:  23 	enzload_id:  ENZLOAD-3HAD60_REV-fabZ
# i:  24 	enzload_id:  ENZLOAD-3HAD80_FWD-fabZ
# i:  25 	enzload_id:  ENZLOAD-3HAD80_REV-fabZ
# i:  28 	enzload_id:  ENZLOAD-3OAR100_FWD-fabG_1283
# i:  29 	enzload_id:  ENZLOAD-3OAR100_REV-fabG_1283
# i:  30 	enzload_id:  ENZLOAD-3OAR100_FWD-fabG_2272
# i:  31 	enzload_id:  ENZLOAD-3OAR100_REV-fabG_2272
# i:  32 	enzload_id:  ENZLOAD-3OAR120_FWD-fabG_1283
# i:  33 	enzload_id:  ENZLOAD-3OAR120_REV-fabG_1283
# i:  34 	enzload_id:  ENZLOAD-3OAR120_FWD-fabG_2272
# i:  35 	enzload_id:  ENZLOAD-3OAR120_REV-fabG_2272
# i:  36 	enzload_id:  ENZLOAD-3OAR140_FWD-fabG_1283
# i:  37 	enzload_id:  ENZLOAD-3OAR140_REV-fabG_1283
# i:  38 	enzload_id:  ENZLOAD-3OAR140_FWD-fabG_2272
# i:  39 	enzload_id:  ENZLOAD-3OAR140_REV-fabG_2272
# i:  40 	enzload_id:  ENZLOAD-3OAR160_FWD-Clo1313_1283
# i:  41 	enzload_id:  ENZLOAD-3OAR160_REV-Clo1313_1283
# i:  42 	enzload_id:  ENZLOAD-3OAR160_FWD-Clo1313_2272
# i:  43 	enzload_id:  ENZLOAD-3OAR160_REV-Clo1313_2272
# i:  44 	enzload_id:  ENZLOAD-3OAR18B_FWD-fabG_1283
# i:  45 	enzload_id:  ENZLOAD-3OAR18B_REV-fabG_1283
# i:  46 	enzload_id:  ENZLOAD-3OAR18B_FWD-fabG_2272
# i:  47 	enzload_id:  ENZLOAD-3OAR18B_REV-fabG_2272
# i:  48 	enzload_id:  ENZLOAD-3OAR40_FWD-fabG_1283
# i:  49 	enzload_id:  ENZLOAD-3OAR40_REV-fabG_1283
# i:  50 	enzload_id:  ENZLOAD-3OAR40_FWD-fabG_2272
# i:  51 	enzload_id:  ENZLOAD-3OAR40_REV-fabG_2272
# i:  52 	enzload_id:  ENZLOAD-3OAR60_FWD-fabG_1283
# i:  53 	enzload_id:  ENZLOAD-3OAR60_REV-fabG_1283
# i:  54 	enzload_id:  ENZLOAD-3OAR60_FWD-fabG_2272
# i:  55 	enzload_id:  ENZLOAD-3OAR60_REV-fabG_2272
# i:  56 	enzload_id:  ENZLOAD-3OAR80_FWD-fabG_1283
# i:  57 	enzload_id:  ENZLOAD-3OAR80_REV-fabG_1283
# i:  58 	enzload_id:  ENZLOAD-3OAR80_FWD-fabG_2272
# i:  59 	enzload_id:  ENZLOAD-3OAR80_REV-fabG_2272
# i:  60 	enzload_id:  ENZLOAD-3OAS100_FWD-fabF
# i:  61 	enzload_id:  ENZLOAD-3OAS100_FWD-fabHA_1281
# i:  62 	enzload_id:  ENZLOAD-3OAS100_FWD-fabHA_2100
# i:  63 	enzload_id:  ENZLOAD-3OAS100_FWD-fabHA_2102
# i:  64 	enzload_id:  ENZLOAD-3OAS100_FWD-pksJL
# i:  65 	enzload_id:  ENZLOAD-3OAS120_FWD-fabF
# i:  66 	enzload_id:  ENZLOAD-3OAS120_FWD-fabHA_1281
# i:  67 	enzload_id:  ENZLOAD-3OAS120_FWD-fabHA_2100
# i:  68 	enzload_id:  ENZLOAD-3OAS120_FWD-fabHA_2102
# i:  69 	enzload_id:  ENZLOAD-3OAS120_FWD-pksJL
# i:  70 	enzload_id:  ENZLOAD-3OAS140_FWD-fabF
# i:  71 	enzload_id:  ENZLOAD-3OAS140_FWD-fabHA_1281
# i:  72 	enzload_id:  ENZLOAD-3OAS140_FWD-fabHA_2100
# i:  73 	enzload_id:  ENZLOAD-3OAS140_FWD-fabHA_2102
# i:  74 	enzload_id:  ENZLOAD-3OAS140_FWD-pksJL
# i:  75 	enzload_id:  ENZLOAD-3OAS160_FWD-fabF
# i:  76 	enzload_id:  ENZLOAD-3OAS160_FWD-fabHA_1281
# i:  77 	enzload_id:  ENZLOAD-3OAS160_FWD-fabHA_2100
# i:  78 	enzload_id:  ENZLOAD-3OAS160_FWD-fabHA_2102
# i:  79 	enzload_id:  ENZLOAD-3OAS160_FWD-pksJL
# i:  80 	enzload_id:  ENZLOAD-3OAS60_FWD-fabF
# i:  81 	enzload_id:  ENZLOAD-3OAS80_FWD-fabF
# i:  82 	enzload_id:  ENZLOAD-3OAS80_FWD-fabHA_1281
# i:  83 	enzload_id:  ENZLOAD-3OAS80_FWD-fabHA_2100
# i:  84 	enzload_id:  ENZLOAD-3OAS80_FWD-fabHA_2102
# i:  85 	enzload_id:  ENZLOAD-3OAS80_FWD-pksJL
# i:  86 	enzload_id:  ENZLOAD-3SALATA_FWD-Clo1313_1467
# i:  87 	enzload_id:  ENZLOAD-3SALATA_REV-Clo1313_1467
# i:  88 	enzload_id:  ENZLOAD-3SALATA_FWD-Clo1313_1657
# i:  89 	enzload_id:  ENZLOAD-3SALATA_REV-Clo1313_1657
# i:  92 	enzload_id:  ENZLOAD-4HTHRS_FWD-ADU73935
# i:  94 	enzload_id:  ENZLOAD-5FLURAPRT2_FWD-thrS
# i:  95 	enzload_id:  ENZLOAD-6TINS5MPOR_FWD-guaB
# i:  96 	enzload_id:  ENZLOAD-6TXAN5MPAML_FWD-guaA
# i:  97 	enzload_id:  ENZLOAD-AABHH_FWD-pepD
# i:  102 	enzload_id:  ENZLOAD-AATC_FWD-Clo1313_1467
# i:  103 	enzload_id:  ENZLOAD-AATC_REV-Clo1313_1467
# i:  104 	enzload_id:  ENZLOAD-AATC_FWD-Clo1313_1657
# i:  105 	enzload_id:  ENZLOAD-AATC_REV-Clo1313_1657
# i:  106 	enzload_id:  ENZLOAD-ABGPT_FWD-glcK
# i:  107 	enzload_id:  ENZLOAD-ABGPT_FWD-xylR
# i:  109 	enzload_id:  ENZLOAD-ACALD_FWD-gbsB_1798
# i:  110 	enzload_id:  ENZLOAD-ACALDy_FWD-gbsB_1798
# i:  111 	enzload_id:  ENZLOAD-ACAS_2ahbut_FWD-ilvBH_0099
# i:  112 	enzload_id:  ENZLOAD-ACAS_2ahbut_FWD-ilvBH_0305
# i:  113 	enzload_id:  ENZLOAD-ACBIPGT_FWD-cobU
# i:  114 	enzload_id:  ENZLOAD-ACBIPGT_REV-cobU
# i:  115 	enzload_id:  ENZLOAD-ACCOAC_FWD-yqjD
# i:  116 	enzload_id:  ENZLOAD-ACGK_FWD-argB
# i:  117 	enzload_id:  ENZLOAD-ACGNMCT_FWD-ADU73322
# i:  118 	enzload_id:  ENZLOAD-ACGS_FWD-argJ
# i:  119 	enzload_id:  ENZLOAD-ACKr_FWD-ackA
# i:  120 	enzload_id:  ENZLOAD-ACKr_REV-ackA
# i:  122 	enzload_id:  ENZLOAD-ACLS_FWD-ivlBH_0099
# i:  123 	enzload_id:  ENZLOAD-ACLS_FWD-ivlBH_0305
# i:  124 	enzload_id:  ENZLOAD-ACNAM9PL_FWD-spsE_0230
# i:  125 	enzload_id:  ENZLOAD-ACNAM9PL_FWD-spsE_2902
# i:  126 	enzload_id:  ENZLOAD-ACNMCT_FWD-ADU73322
# i:  127 	enzload_id:  ENZLOAD-ACNPLYS_FWD-spsE_0230
# i:  128 	enzload_id:  ENZLOAD-ACNPLYS_FWD-spsE_2902
# i:  129 	enzload_id:  ENZLOAD-ACOATA_FWD-fabHA_1281
# i:  130 	enzload_id:  ENZLOAD-ACOATA_FWD-fabHA_2100
# i:  131 	enzload_id:  ENZLOAD-ACOATA_FWD-fabHA_2102
# i:  132 	enzload_id:  ENZLOAD-ACONT_FWD-leuC
# i:  133 	enzload_id:  ENZLOAD-ACONT_REV-leuC
# i:  134 	enzload_id:  ENZLOAD-ACOTA_FWD-argD
# i:  135 	enzload_id:  ENZLOAD-ACOTA_REV-argD
# i:  136 	enzload_id:  ENZLOAD-ACPS1_FWD-Spf
# i:  137 	enzload_id:  ENZLOAD-ACS2_FWD-ytcI
# i:  140 	enzload_id:  ENZLOAD-ADA_FWD-ylmD
# i:  141 	enzload_id:  ENZLOAD-ADA_REV-ylmD
# i:  142 	enzload_id:  ENZLOAD-ADAPAT_FWD-yugH
# i:  144 	enzload_id:  ENZLOAD-ADCPS1_FWD-cobD
# i:  145 	enzload_id:  ENZLOAD-ADCPS2_FWD-cobD
# i:  146 	enzload_id:  ENZLOAD-ADEabc_FWD-nupOPQ
# i:  147 	enzload_id:  ENZLOAD-ADEabc_REV-nupOPQ
# i:  148 	enzload_id:  ENZLOAD-ADK1_FWD-adk
# i:  149 	enzload_id:  ENZLOAD-ADK1_REV-adk
# i:  150 	enzload_id:  ENZLOAD-ADK2_FWD-adk
# i:  151 	enzload_id:  ENZLOAD-ADK2_REV-adk
# i:  152 	enzload_id:  ENZLOAD-ADMDC_FWD-speD
# i:  153 	enzload_id:  ENZLOAD-ADOCBIK_FWD-cobU
# i:  154 	enzload_id:  ENZLOAD-ADOCBIK2_FWD-cobU
# i:  155 	enzload_id:  ENZLOAD-ADOCBLabc_FWD-fepCCDyvrC
# i:  156 	enzload_id:  ENZLOAD-ADOCBLS_FWD-cobS
# i:  157 	enzload_id:  ENZLOAD-ADPCOAL_FWD-grsT
# i:  158 	enzload_id:  ENZLOAD-ADPCOAL_FWD-lcfA
# i:  159 	enzload_id:  ENZLOAD-ADPCOAL_FWD-lcfB
# i:  160 	enzload_id:  ENZLOAD-ADPCOAL_FWD-ldeI
# i:  161 	enzload_id:  ENZLOAD-ADPRDP_FWD-nudF
# i:  162 	enzload_id:  ENZLOAD-ADPT_FWD-apt
# i:  163 	enzload_id:  ENZLOAD-ADPT_FWD-hptA
# i:  164 	enzload_id:  ENZLOAD-ADPT2_FWD-apt
# i:  165 	enzload_id:  ENZLOAD-ADPT2_REV-apt
# i:  166 	enzload_id:  ENZLOAD-ADPT2_FWD-dtd
# i:  167 	enzload_id:  ENZLOAD-ADPT2_REV-dtd
# i:  168 	enzload_id:  ENZLOAD-ADSK_FWD-tufA
# i:  169 	enzload_id:  ENZLOAD-ADSL1r_FWD-purB
# i:  170 	enzload_id:  ENZLOAD-ADSL1r_REV-purB
# i:  171 	enzload_id:  ENZLOAD-ADSL2r_FWD-purB
# i:  172 	enzload_id:  ENZLOAD-ADSL2r_REV-purB
# i:  173 	enzload_id:  ENZLOAD-AGDC_FWD-nagA
# i:  174 	enzload_id:  ENZLOAD-AGMT_FWD-speB
# i:  175 	enzload_id:  ENZLOAD-AGPR_FWD-argC
# i:  176 	enzload_id:  ENZLOAD-AGPR_REV-argC
# i:  177 	enzload_id:  ENZLOAD-AGT_FWD-pucG
# i:  178 	enzload_id:  ENZLOAD-AGT_REV-pucG
# i:  179 	enzload_id:  ENZLOAD-AHCi_FWD-SAHH
# i:  180 	enzload_id:  ENZLOAD-AHDTPHL_FWD-folE
# i:  181 	enzload_id:  ENZLOAD-AHEXASE3_FWD-bglX
# i:  182 	enzload_id:  ENZLOAD-AHSERL2_FWD-mccB_2335
# i:  183 	enzload_id:  ENZLOAD-AHSERL2_FWD-mccB_2534
# i:  184 	enzload_id:  ENZLOAD-AHSERL4_FWD-cysK
# i:  185 	enzload_id:  ENZLOAD-AHSERL4_FWD-mccA
# i:  186 	enzload_id:  ENZLOAD-AHSERL4_FWD-mccB_2534
# i:  187 	enzload_id:  ENZLOAD-AHSERL4_FWD-mccB_2535
# i:  188 	enzload_id:  ENZLOAD-AHSL_FWD-mccB
# i:  189 	enzload_id:  ENZLOAD-AHSL_REV-mccB
# i:  190 	enzload_id:  ENZLOAD-AICART_FWD-purH
# i:  191 	enzload_id:  ENZLOAD-AICART_REV-purH
# i:  192 	enzload_id:  ENZLOAD-AIRC3_FWD-purE
# i:  194 	enzload_id:  ENZLOAD-ALAALAr_FWD-ddl
# i:  195 	enzload_id:  ENZLOAD-ALAALAr_FWD-pyrAB
# i:  196 	enzload_id:  ENZLOAD-ALAR_FWD-alrB
# i:  197 	enzload_id:  ENZLOAD-ALAR_FWD-ylmE
# i:  198 	enzload_id:  ENZLOAD-ALAt_FWD-azlCD
# i:  199 	enzload_id:  ENZLOAD-ALAt_REV-azlCD
# i:  200 	enzload_id:  ENZLOAD-ALATRS_FWD-alaS
# i:  201 	enzload_id:  ENZLOAD-ALCD22xi_FWD-cotJA
# i:  202 	enzload_id:  ENZLOAD-ALCD22xi2_FWD-cotJA
# i:  203 	enzload_id:  ENZLOAD-ALCD23xi_FWD-gbsB_1798
# i:  204 	enzload_id:  ENZLOAD-ALCD23xi2_FWD-cotJA
# i:  205 	enzload_id:  ENZLOAD-ALCD23yi_FWD-gbsB_1798
# i:  206 	enzload_id:  ENZLOAD-ALCD2x_FWD-gbsB_1798
# i:  207 	enzload_id:  ENZLOAD-ALCD2y_FWD-gbsB_1798
# i:  208 	enzload_id:  ENZLOAD-ALCD3MBOH_FWD-cotJA
# i:  209 	enzload_id:  ENZLOAD-ALCD3x_FWD-cotJA
# i:  210 	enzload_id:  ENZLOAD-ALDD1_FWD-aldX
# i:  211 	enzload_id:  ENZLOAD-ALDD1_REV-aldX
# i:  212 	enzload_id:  ENZLOAD-ALDD20x_FWD-Clo1313_2911
# i:  213 	enzload_id:  ENZLOAD-ALDD20x_REV-Clo1313_2911
# i:  214 	enzload_id:  ENZLOAD-ALDD22x_FWD-aldX
# i:  215 	enzload_id:  ENZLOAD-ALDD2x_FWD-aldX
# i:  216 	enzload_id:  ENZLOAD-ALDH_FWD-aldX
# i:  217 	enzload_id:  ENZLOAD-ALLAS_FWD-ltaSC_2059
# i:  218 	enzload_id:  ENZLOAD-ALLAS_FWD-ltaSC_2170
# i:  219 	enzload_id:  ENZLOAD-AMAOTr_FWD-bioA
# i:  220 	enzload_id:  ENZLOAD-AMAOTr_REV-bioA
# i:  221 	enzload_id:  ENZLOAD-AMPTASECG_FWD-pepD
# i:  222 	enzload_id:  ENZLOAD-AMPTASECG_REV-pepD
# i:  223 	enzload_id:  ENZLOAD-AMUAAH_FWD-cwlD
# i:  224 	enzload_id:  ENZLOAD-AMUAAH_FWD-cwlJ
# i:  225 	enzload_id:  ENZLOAD-AMUAAH_FWD-lysM
# i:  226 	enzload_id:  ENZLOAD-AMUAAH_FWD-sleB_0046
# i:  227 	enzload_id:  ENZLOAD-AMUAAH_FWD-sleB_2624
# i:  228 	enzload_id:  ENZLOAD-AMUAAH_FWD-SLH
# i:  229 	enzload_id:  ENZLOAD-AMUAAH_FWD-ykvT
# i:  230 	enzload_id:  ENZLOAD-AMUAAH_FWD-yqiI_1176
# i:  231 	enzload_id:  ENZLOAD-AMUAAH_FWD-yqiI_1198
# i:  232 	enzload_id:  ENZLOAD-AMUAAH_FWD-yqiI_2048
# i:  233 	enzload_id:  ENZLOAD-ANPRT_FWD-trpD
# i:  234 	enzload_id:  ENZLOAD-ANS_FWD-pabA
# i:  236 	enzload_id:  ENZLOAD-AOXSr_FWD-bioF
# i:  237 	enzload_id:  ENZLOAD-AOXSr_REV-bioF
# i:  238 	enzload_id:  ENZLOAD-AOXSr2_FWD-bioF
# i:  239 	enzload_id:  ENZLOAD-APCPT_FWD-coaX
# i:  240 	enzload_id:  ENZLOAD-APCS_FWD-speE_2
# i:  241 	enzload_id:  ENZLOAD-APCS_FWD-speE_4
# i:  242 	enzload_id:  ENZLOAD-APL_FWD-ilvBH_0099
# i:  243 	enzload_id:  ENZLOAD-APL_FWD-ilvBH_0305
# i:  244 	enzload_id:  ENZLOAD-APNPT_FWD-coaX
# i:  245 	enzload_id:  ENZLOAD-APNTPM_FWD-folE
# i:  246 	enzload_id:  ENZLOAD-APNTPM_REV-folE
# i:  247 	enzload_id:  ENZLOAD-APPAT_FWD-coaD
# i:  248 	enzload_id:  ENZLOAD-APRAUR_FWD-ribD
# i:  249 	enzload_id:  ENZLOAD-ARGabc_FWD-artPhisMglnQ
# i:  250 	enzload_id:  ENZLOAD-ARGDC_FWD-speA
# i:  251 	enzload_id:  ENZLOAD-ARGDC_REV-speA
# i:  252 	enzload_id:  ENZLOAD-ARGSL_FWD-argH
# i:  253 	enzload_id:  ENZLOAD-ARGSL_REV-argH
# i:  254 	enzload_id:  ENZLOAD-ARGSS_FWD-argG
# i:  255 	enzload_id:  ENZLOAD-ARGSS_REV-argG
# i:  256 	enzload_id:  ENZLOAD-ARGTRS_FWD-argS
# i:  257 	enzload_id:  ENZLOAD-AROH_FWD-pheE
# i:  258 	enzload_id:  ENZLOAD-ASAD_FWD-asd
# i:  259 	enzload_id:  ENZLOAD-ASAD_REV-asd
# i:  260 	enzload_id:  ENZLOAD-ASAHL_FWD-dapA
# i:  261 	enzload_id:  ENZLOAD-ASNabc_FWD-artPhisMglnQ
# i:  262 	enzload_id:  ENZLOAD-ASNabc_REV-artPhisMglnQ
# i:  263 	enzload_id:  ENZLOAD-ASNabc_FWD-tycBC
# i:  264 	enzload_id:  ENZLOAD-ASNabc_REV-tycBC
# i:  265 	enzload_id:  ENZLOAD-ASNS1_FWD-ADU74738
# i:  266 	enzload_id:  ENZLOAD-ASNS1_FWD-asnA
# i:  267 	enzload_id:  ENZLOAD-ASNS2_FWD-ADU74738
# i:  268 	enzload_id:  ENZLOAD-ASNS2_FWD-asnA
# i:  269 	enzload_id:  ENZLOAD-ASNTRAT_FWD-gatABC_0
# i:  270 	enzload_id:  ENZLOAD-ASNTRAT_FWD-gatABC_1
# i:  271 	enzload_id:  ENZLOAD-ASNTRS_FWD-asnC
# i:  272 	enzload_id:  ENZLOAD-ASP1DC_FWD-panD
# i:  273 	enzload_id:  ENZLOAD-ASPabc_FWD-artPhisMglnQ
# i:  274 	enzload_id:  ENZLOAD-ASPabc_FWD-tycBC
# i:  275 	enzload_id:  ENZLOAD-ASPCT_FWD-pyrB
# i:  276 	enzload_id:  ENZLOAD-ASPK_FWD-thrD
# i:  277 	enzload_id:  ENZLOAD-ASPO2_FWD-nadB
# i:  278 	enzload_id:  ENZLOAD-ASPO2y_FWD-nadB
# i:  279 	enzload_id:  ENZLOAD-ASPTA_FWD-aspB
# i:  280 	enzload_id:  ENZLOAD-ASPTA_FWD-yhdR
# i:  281 	enzload_id:  ENZLOAD-ASPTRS_FWD-aspS_0923
# i:  282 	enzload_id:  ENZLOAD-ASPTRS_FWD-aspS_2307
# i:  283 	enzload_id:  ENZLOAD-ATAS_FWD-ltaSC_2059
# i:  284 	enzload_id:  ENZLOAD-ATAS_FWD-ltaSC_2170
# i:  285 	enzload_id:  ENZLOAD-ATPM_FWD-maf
# i:  287 	enzload_id:  ENZLOAD-ATPM_FWD-nudF
# i:  288 	enzload_id:  ENZLOAD-ATPM_FWD-rsgA_1662
# i:  289 	enzload_id:  ENZLOAD-ATPM_FWD-rsgA_2278
# i:  290 	enzload_id:  ENZLOAD-ATPPRT_FWD-hisGZ
# i:  291 	enzload_id:  ENZLOAD-BACCL_FWD-birA
# i:  296 	enzload_id:  ENZLOAD-BDG2HCGHD_FWD-gmuD
# i:  297 	enzload_id:  ENZLOAD-BDG2HCGHD_REV-gmuD
# i:  298 	enzload_id:  ENZLOAD-BDG2HCGHD_FWD-nagZ
# i:  299 	enzload_id:  ENZLOAD-BDG2HCGHD_REV-nagZ
# i:  300 	enzload_id:  ENZLOAD-BDG2HCGHD_FWD-xynD
# i:  301 	enzload_id:  ENZLOAD-BDG2HCGHD_REV-xynD
# i:  302 	enzload_id:  ENZLOAD-BGGHL_FWD-xynD
# i:  303 	enzload_id:  ENZLOAD-BGGHL_REV-xynD
# i:  304 	enzload_id:  ENZLOAD-BHPR_FWD-capD_0239
# i:  305 	enzload_id:  ENZLOAD-BHPR_REV-capD_0239
# i:  306 	enzload_id:  ENZLOAD-BHPR_FWD-capD_2905
# i:  307 	enzload_id:  ENZLOAD-BHPR_REV-capD_2905
# i:  308 	enzload_id:  ENZLOAD-BHPR_FWD-flaA
# i:  309 	enzload_id:  ENZLOAD-BHPR_REV-flaA
# i:  310 	enzload_id:  ENZLOAD-BIF_FWD-HndACD
# i:  311 	enzload_id:  ENZLOAD-BIF_FWD-HndABCD
# i:  312 	enzload_id:  ENZLOAD-BIF_REV-HndACD
# i:  313 	enzload_id:  ENZLOAD-BIF_REV-HndABCD
# i:  314 	enzload_id:  ENZLOAD-BPNT_FWD-tufA
# i:  315 	enzload_id:  ENZLOAD-BTCOARx_FWD-gbsB_1798
# i:  316 	enzload_id:  ENZLOAD-BTDD_M_FWD-BDH
# i:  317 	enzload_id:  ENZLOAD-BTDD_M_FWD-tuaD
# i:  318 	enzload_id:  ENZLOAD-BTDD_RR_FWD-BDH
# i:  319 	enzload_id:  ENZLOAD-BTDD_RR_FWD-tuaD
# i:  324 	enzload_id:  ENZLOAD-BTS6_FWD-bioB
# i:  325 	enzload_id:  ENZLOAD-BTS6_FWD-hydE
# i:  330 	enzload_id:  ENZLOAD-CAt7r_FWD-ECM27
# i:  331 	enzload_id:  ENZLOAD-CAt7r_REV-ECM27
# i:  332 	enzload_id:  ENZLOAD-CBIAT_FWD-cobAcobObtuR
# i:  333 	enzload_id:  ENZLOAD-CBPS_FWD-carAB_1267
# i:  334 	enzload_id:  ENZLOAD-CBPS_FWD-carAB_2559
# i:  335 	enzload_id:  ENZLOAD-CDGPT_FWD-pgsA
# i:  336 	enzload_id:  ENZLOAD-CDGS_FWD-cdsA
# i:  339 	enzload_id:  ENZLOAD-CDGUNPD_FWD-dgcW
# i:  340 	enzload_id:  ENZLOAD-CDGUNPD_REV-dgcW
# i:  341 	enzload_id:  ENZLOAD-CDP4D6DGLCRx_FWD-spsC
# i:  342 	enzload_id:  ENZLOAD-CDP4D6DGLCRx2_FWD-spsC
# i:  343 	enzload_id:  ENZLOAD-CDPGLC46DH_FWD-Clo1313_0147
# i:  344 	enzload_id:  ENZLOAD-CDPMEK_FWD-ispE
# i:  345 	enzload_id:  ENZLOAD-CEL2abc_FWD-MSTS_0
# i:  346 	enzload_id:  ENZLOAD-CEL2abc_FWD-MSTS_1
# i:  347 	enzload_id:  ENZLOAD-CEL2abc_FWD-MSTS_2
# i:  348 	enzload_id:  ENZLOAD-CEL2abc_FWD-MSTS_3
# i:  349 	enzload_id:  ENZLOAD-CEL3abc_FWD-MSTS_0
# i:  350 	enzload_id:  ENZLOAD-CEL3abc_FWD-MSTS_1
# i:  351 	enzload_id:  ENZLOAD-CEL3abc_FWD-MSTS_2
# i:  352 	enzload_id:  ENZLOAD-CEL3abc_FWD-MSTS_3
# i:  353 	enzload_id:  ENZLOAD-CEL4abc_FWD-MSTS_0
# i:  354 	enzload_id:  ENZLOAD-CEL4abc_FWD-MSTS_1
# i:  355 	enzload_id:  ENZLOAD-CEL4abc_FWD-MSTS_2
# i:  356 	enzload_id:  ENZLOAD-CEL4abc_FWD-MSTS_3
# i:  357 	enzload_id:  ENZLOAD-CEL5abc_FWD-MSTS_0
# i:  358 	enzload_id:  ENZLOAD-CEL5abc_FWD-MSTS_1
# i:  359 	enzload_id:  ENZLOAD-CEL5abc_FWD-MSTS_2
# i:  360 	enzload_id:  ENZLOAD-CEL5abc_FWD-MSTS_3
# i:  361 	enzload_id:  ENZLOAD-CEL6abc_FWD-MSTS_0
# i:  362 	enzload_id:  ENZLOAD-CEL6abc_FWD-MSTS_1
# i:  363 	enzload_id:  ENZLOAD-CEL6abc_FWD-MSTS_2
# i:  364 	enzload_id:  ENZLOAD-CEL6abc_FWD-MSTS_3
# i:  365 	enzload_id:  ENZLOAD-CEPA_FWD-ADU75001
# i:  366 	enzload_id:  ENZLOAD-CEPA2_FWD-glgP
# i:  367 	enzload_id:  ENZLOAD-CEPA3_FWD-glgP
# i:  368 	enzload_id:  ENZLOAD-CEPA4_FWD-glgP
# i:  369 	enzload_id:  ENZLOAD-CEPA5_FWD-glgP
# i:  370 	enzload_id:  ENZLOAD-CGGH_FWD-gmuD
# i:  371 	enzload_id:  ENZLOAD-CGGH_FWD-nagZ
# i:  372 	enzload_id:  ENZLOAD-CGGH_FWD-xynD
# i:  373 	enzload_id:  ENZLOAD-CHORM_FWD-aroH
# i:  374 	enzload_id:  ENZLOAD-CHORM_FWD-thrR
# i:  375 	enzload_id:  ENZLOAD-CHRS_FWD-aroC
# i:  376 	enzload_id:  ENZLOAD-CITCIb_FWD-leuCD
# i:  377 	enzload_id:  ENZLOAD-CITCIb_REV-leuCD
# i:  378 	enzload_id:  ENZLOAD-CITMS_FWD-leuA_0102
# i:  379 	enzload_id:  ENZLOAD-CITMS_FWD-leuA_0857
# i:  380 	enzload_id:  ENZLOAD-CITt2_FWD-arsBnhaD
# i:  381 	enzload_id:  ENZLOAD-CITt2_REV-arsBnhaD
# i:  382 	enzload_id:  ENZLOAD-CLS_FWD-clsC
# i:  383 	enzload_id:  ENZLOAD-CLS2_FWD-clsC
# i:  384 	enzload_id:  ENZLOAD-CMIPDCOAL_FWD-grsT
# i:  385 	enzload_id:  ENZLOAD-CMIPDCOAL_FWD-lcfA
# i:  386 	enzload_id:  ENZLOAD-CMIPDCOAL_FWD-lcfB
# i:  387 	enzload_id:  ENZLOAD-CMIPDCOAL_FWD-ldeI
# i:  388 	enzload_id:  ENZLOAD-CMS_FWD-ispD
# i:  392 	enzload_id:  ENZLOAD-COabc_FWD-cbiOQM
# i:  393 	enzload_id:  ENZLOAD-COabc_FWD-ecfAcbiQM
# i:  396 	enzload_id:  ENZLOAD-CPCOAL_FWD-grsT
# i:  397 	enzload_id:  ENZLOAD-CPCOAL_FWD-lcfA
# i:  398 	enzload_id:  ENZLOAD-CPCOAL_FWD-lcfB
# i:  399 	enzload_id:  ENZLOAD-CPCOAL_FWD-ldeI
# i:  400 	enzload_id:  ENZLOAD-CPHL_FWD-AXE1
# i:  401 	enzload_id:  ENZLOAD-CPPPGO2_FWD-ADU74870
# i:  402 	enzload_id:  ENZLOAD-CPPPGO2_FWD-ADU75118
# i:  403 	enzload_id:  ENZLOAD-CPPPGO2_FWD-albA_0948
# i:  404 	enzload_id:  ENZLOAD-CPPPGO2_FWD-albA_1312
# i:  405 	enzload_id:  ENZLOAD-CPPPGO2_FWD-albA_1997
# i:  406 	enzload_id:  ENZLOAD-CPPPGO2_FWD-hemN
# i:  407 	enzload_id:  ENZLOAD-CPPPGO2_FWD-hemN_1
# i:  408 	enzload_id:  ENZLOAD-CPPPGO2_FWD-hemN_2
# i:  409 	enzload_id:  ENZLOAD-CPPPGO2_FWD-hemZ_0912
# i:  410 	enzload_id:  ENZLOAD-CPPPGO2_FWD-hemZ_0735
# i:  411 	enzload_id:  ENZLOAD-CPPPGO2_FWD-hydE
# i:  412 	enzload_id:  ENZLOAD-CPPPGO2_FWD-miaB
# i:  413 	enzload_id:  ENZLOAD-CPPPGO2_FWD-moaA_0626
# i:  414 	enzload_id:  ENZLOAD-CPPPGO2_FWD-moaA_2334
# i:  415 	enzload_id:  ENZLOAD-CPPPGO2_FWD-moaA_0137
# i:  416 	enzload_id:  ENZLOAD-CPPPGO2_FWD-moaA_0138
# i:  417 	enzload_id:  ENZLOAD-CPPPGO2_FWD-moaA_0139
# i:  418 	enzload_id:  ENZLOAD-CPPPGO2_FWD-moaA_0142
# i:  419 	enzload_id:  ENZLOAD-CPPPGO2_FWD-pflA
# i:  420 	enzload_id:  ENZLOAD-CPPPGO2_FWD-queE
# i:  421 	enzload_id:  ENZLOAD-CPPPGO2_FWD-skfB
# i:  422 	enzload_id:  ENZLOAD-CPPPGO2_FWD-ygiQ
# i:  423 	enzload_id:  ENZLOAD-CS_FWD-citA
# i:  424 	enzload_id:  ENZLOAD-CS_REV-citA
# i:  425 	enzload_id:  ENZLOAD-CS_FWD-leuA_0708
# i:  426 	enzload_id:  ENZLOAD-CS_REV-leuA_0708
# i:  427 	enzload_id:  ENZLOAD-CTPS1_FWD-pyrG
# i:  428 	enzload_id:  ENZLOAD-CTPS2_FWD-pyrG
# i:  429 	enzload_id:  ENZLOAD-CYRDAAT_FWD-cobAcobObtuR
# i:  430 	enzload_id:  ENZLOAD-CYS_FWD-speA
# i:  431 	enzload_id:  ENZLOAD-CYS_REV-speA
# i:  432 	enzload_id:  ENZLOAD-CYSDES_FWD-iscSB
# i:  433 	enzload_id:  ENZLOAD-CYSDES_FWD-iscSU
# i:  436 	enzload_id:  ENZLOAD-CYSS_FWD-cysK
# i:  437 	enzload_id:  ENZLOAD-CYSS_FWD-mccA
# i:  438 	enzload_id:  ENZLOAD-CYSTA_FWD-aspB
# i:  439 	enzload_id:  ENZLOAD-CYSTA_FWD-yhdR
# i:  440 	enzload_id:  ENZLOAD-CYSTRS_FWD-cysS
# i:  441 	enzload_id:  ENZLOAD-CYTD_FWD-cdd_1145
# i:  442 	enzload_id:  ENZLOAD-CYTD_FWD-cdd_2348
# i:  443 	enzload_id:  ENZLOAD-CYTDabc_FWD-nupOPQ
# i:  444 	enzload_id:  ENZLOAD-CYTDabc_REV-nupOPQ
# i:  445 	enzload_id:  ENZLOAD-CYTDK1_FWD-thrS
# i:  446 	enzload_id:  ENZLOAD-CYTDK2_FWD-thrS
# i:  447 	enzload_id:  ENZLOAD-CYTK1_FWD-cmk
# i:  448 	enzload_id:  ENZLOAD-CYTK1_REV-cmk
# i:  449 	enzload_id:  ENZLOAD-CYTK2_FWD-cmk
# i:  450 	enzload_id:  ENZLOAD-DADK_FWD-adk
# i:  454 	enzload_id:  ENZLOAD-DAPDC_FWD-lysA
# i:  455 	enzload_id:  ENZLOAD-DAPE_FWD-dapF
# i:  456 	enzload_id:  ENZLOAD-DAPE_REV-dapF
# i:  457 	enzload_id:  ENZLOAD-DATCY_FWD-thrS
# i:  458 	enzload_id:  ENZLOAD-DATUP_FWD-thrS
# i:  459 	enzload_id:  ENZLOAD-DB4PS_FWD-ribBA
# i:  460 	enzload_id:  ENZLOAD-DBTS_FWD-bioD
# i:  461 	enzload_id:  ENZLOAD-DCMPDA_FWD-comEB
# i:  462 	enzload_id:  ENZLOAD-DCTCP_FWD-Clo1313_1891
# i:  463 	enzload_id:  ENZLOAD-DCTPD_FWD-dcd
# i:  464 	enzload_id:  ENZLOAD-DCTPD2_FWD-dcd
# i:  465 	enzload_id:  ENZLOAD-DCTUP_FWD-thrS
# i:  466 	enzload_id:  ENZLOAD-DCYTD_FWD-cdd_1145
# i:  467 	enzload_id:  ENZLOAD-DCYTD_FWD-cdd_2348
# i:  468 	enzload_id:  ENZLOAD-DGK1_FWD-gmk
# i:  469 	enzload_id:  ENZLOAD-DGTCY_FWD-thrS
# i:  470 	enzload_id:  ENZLOAD-DGTUP_FWD-thrS
# i:  471 	enzload_id:  ENZLOAD-DHAD1_FWD-ilvD
# i:  472 	enzload_id:  ENZLOAD-DHAD2_FWD-ilvD
# i:  473 	enzload_id:  ENZLOAD-DHDOR_FWD-ddh
# i:  474 	enzload_id:  ENZLOAD-DHDPRx_r_FWD-dapB_1090
# i:  475 	enzload_id:  ENZLOAD-DHDPRx_r_REV-dapB_1090
# i:  476 	enzload_id:  ENZLOAD-DHDPRx_r_FWD-dapB_1253
# i:  477 	enzload_id:  ENZLOAD-DHDPRx_r_REV-dapB_1253
# i:  478 	enzload_id:  ENZLOAD-DHFOR_FWD-dfrA
# i:  479 	enzload_id:  ENZLOAD-DHFOR2_FWD-dfrA
# i:  480 	enzload_id:  ENZLOAD-DHFR_FWD-dfrA
# i:  481 	enzload_id:  ENZLOAD-DHFR2i_FWD-dfrA
# i:  482 	enzload_id:  ENZLOAD-DHFS_FWD-folC
# i:  483 	enzload_id:  ENZLOAD-DHNAOT4_FWD-menA
# i:  484 	enzload_id:  ENZLOAD-DHNPA2r_FWD-folB
# i:  485 	enzload_id:  ENZLOAD-DHORD_NAD_FWD-pyrDK
# i:  486 	enzload_id:  ENZLOAD-DHPPDA2_FWD-ribD
# i:  487 	enzload_id:  ENZLOAD-DHPS_FWD-folP
# i:  488 	enzload_id:  ENZLOAD-DHPS2_1_FWD-folP
# i:  489 	enzload_id:  ENZLOAD-DHQS_FWD-aroB
# i:  490 	enzload_id:  ENZLOAD-DHR_FWD-pyrC
# i:  491 	enzload_id:  ENZLOAD-DHR_REV-pyrC
# i:  492 	enzload_id:  ENZLOAD-DLDLBT_FWD-ribH
# i:  496 	enzload_id:  ENZLOAD-DMATT_FWD-ispA
# i:  497 	enzload_id:  ENZLOAD-DMPPS_FWD-rpfA
# i:  498 	enzload_id:  ENZLOAD-DOLPMT_FWD-ykcC_0645
# i:  499 	enzload_id:  ENZLOAD-DOLPMT_FWD-ykcC_0648
# i:  500 	enzload_id:  ENZLOAD-DOLPMT_FWD-ykcC_0650
# i:  501 	enzload_id:  ENZLOAD-DPCOAK_FWD-coaE
# i:  502 	enzload_id:  ENZLOAD-DPHS_FWD-aroX_1340
# i:  503 	enzload_id:  ENZLOAD-DPHS_FWD-aroX_2468
# i:  505 	enzload_id:  ENZLOAD-DQDH_FWD-yqhS
# i:  506 	enzload_id:  ENZLOAD-DQDH_REV-yqhS
# i:  507 	enzload_id:  ENZLOAD-DRPA_FWD-deoC_2349
# i:  508 	enzload_id:  ENZLOAD-DRPA_FWD-deoC_2615
# i:  509 	enzload_id:  ENZLOAD-DRPA_FWD-fruK
# i:  510 	enzload_id:  ENZLOAD-DTMPK_FWD-Tmk
# i:  511 	enzload_id:  ENZLOAD-DTMPK_REV-Tmk
# i:  512 	enzload_id:  ENZLOAD-DTTGY_FWD-thrS
# i:  513 	enzload_id:  ENZLOAD-DTTUP_FWD-thrS
# i:  514 	enzload_id:  ENZLOAD-DURIPP_FWD-deoD
# i:  515 	enzload_id:  ENZLOAD-DURIPP_REV-deoD
# i:  516 	enzload_id:  ENZLOAD-DURIPP_FWD-pupG_1056
# i:  517 	enzload_id:  ENZLOAD-DURIPP_REV-pupG_1056
# i:  518 	enzload_id:  ENZLOAD-DURIPP_FWD-ylmD
# i:  519 	enzload_id:  ENZLOAD-DURIPP_REV-ylmD
# i:  520 	enzload_id:  ENZLOAD-DUTCP_FWD-thrS
# i:  521 	enzload_id:  ENZLOAD-DUTPDP_FWD-dutA
# i:  522 	enzload_id:  ENZLOAD-DUTUP_FWD-thrS
# i:  523 	enzload_id:  ENZLOAD-DXPS_FWD-dxs
# i:  524 	enzload_id:  ENZLOAD-DXRI_FWD-dxr
# i:  526 	enzload_id:  ENZLOAD-EAR100x_FWD-fabI
# i:  527 	enzload_id:  ENZLOAD-EAR100x_REV-fabI
# i:  528 	enzload_id:  ENZLOAD-EAR120x_FWD-fabI
# i:  529 	enzload_id:  ENZLOAD-EAR120x_REV-fabI
# i:  530 	enzload_id:  ENZLOAD-EAR140x_FWD-fabI
# i:  531 	enzload_id:  ENZLOAD-EAR140x_REV-fabI
# i:  532 	enzload_id:  ENZLOAD-EAR40x_FWD-fabI
# i:  533 	enzload_id:  ENZLOAD-EAR40x_REV-fabI
# i:  534 	enzload_id:  ENZLOAD-EAR60x_FWD-fabI
# i:  535 	enzload_id:  ENZLOAD-EAR60x_REV-fabI
# i:  536 	enzload_id:  ENZLOAD-EAR80x_FWD-fabI
# i:  537 	enzload_id:  ENZLOAD-EAR80x_REV-fabI
# i:  538 	enzload_id:  ENZLOAD-ECH_FWD-hycEechDhycGNADHdhnuoL
# i:  539 	enzload_id:  ENZLOAD-ECH_3hivcoa_FWD-ldeF
# i:  540 	enzload_id:  ENZLOAD-ECH_3hivcoa_REV-ldeF
# i:  541 	enzload_id:  ENZLOAD-ECOAH1_FWD-ldeF
# i:  542 	enzload_id:  ENZLOAD-ECOAH1_REV-ldeF
# i:  543 	enzload_id:  ENZLOAD-ECOAH2_FWD-ldeF
# i:  544 	enzload_id:  ENZLOAD-ECOAH2_REV-ldeF
# i:  545 	enzload_id:  ENZLOAD-ECOAH2c2_FWD-capD_0239
# i:  546 	enzload_id:  ENZLOAD-ECOAH2c2_REV-capD_0239
# i:  547 	enzload_id:  ENZLOAD-ECOAH2c2_FWD-capD_2905
# i:  548 	enzload_id:  ENZLOAD-ECOAH2c2_REV-capD_2905
# i:  549 	enzload_id:  ENZLOAD-ECOAH2c2_FWD-flaA
# i:  550 	enzload_id:  ENZLOAD-ECOAH2c2_REV-flaA
# i:  551 	enzload_id:  ENZLOAD-ECOAH3_FWD-ldeF
# i:  552 	enzload_id:  ENZLOAD-ECOAH3_REV-ldeF
# i:  553 	enzload_id:  ENZLOAD-ECOAH4_FWD-ldeF
# i:  554 	enzload_id:  ENZLOAD-ECOAH4_REV-ldeF
# i:  555 	enzload_id:  ENZLOAD-ECOAH5_FWD-ldeF
# i:  556 	enzload_id:  ENZLOAD-ECOAH5_REV-ldeF
# i:  557 	enzload_id:  ENZLOAD-ECOAH6_FWD-ldeF
# i:  558 	enzload_id:  ENZLOAD-ECOAH6_REV-ldeF
# i:  559 	enzload_id:  ENZLOAD-ECOAH7_FWD-ldeF
# i:  560 	enzload_id:  ENZLOAD-ECOAH7_REV-ldeF
# i:  561 	enzload_id:  ENZLOAD-ECOAH9ir_FWD-ldeF
# i:  562 	enzload_id:  ENZLOAD-ECOAH9ir_REV-ldeF
# i:  563 	enzload_id:  ENZLOAD-EGMEST_FWD-pnbA
# i:  564 	enzload_id:  ENZLOAD-EHGLAT_FWD-aspB
# i:  565 	enzload_id:  ENZLOAD-EHGLAT_REV-aspB
# i:  566 	enzload_id:  ENZLOAD-EHGLAT_FWD-yhdR
# i:  567 	enzload_id:  ENZLOAD-EHGLAT_REV-yhdR
# i:  568 	enzload_id:  ENZLOAD-ENO_FWD-eno
# i:  569 	enzload_id:  ENZLOAD-ENO_REV-eno
# i:  588 	enzload_id:  ENZLOAD-EXCH_cell3_e_REV-SBP_cellx
# i:  590 	enzload_id:  ENZLOAD-EXCH_cell4_e_REV-SBP_cellx
# i:  592 	enzload_id:  ENZLOAD-EXCH_cell5_e_REV-SBP_cellx
# i:  594 	enzload_id:  ENZLOAD-EXCH_cell6_e_REV-SBP_cellx
# i:  596 	enzload_id:  ENZLOAD-EXCH_cellb_e_REV-SBP_cellx
# i:  616 	enzload_id:  ENZLOAD-EXCH_glc__D_e_REV-SBP_cellx
# i:  680 	enzload_id:  ENZLOAD-F6PPT_FWD-pfkA_0997
# i:  681 	enzload_id:  ENZLOAD-F6PPT_FWD-pfkA_1876
# i:  682 	enzload_id:  ENZLOAD-FACOAL160_FWD-ADU74092
# i:  683 	enzload_id:  ENZLOAD-FADDP_FWD-mazG_0245
# i:  684 	enzload_id:  ENZLOAD-FADDP_FWD-mazG_0083
# i:  687 	enzload_id:  ENZLOAD-FASOD_FWD-yhdG
# i:  688 	enzload_id:  ENZLOAD-FASOD_REV-yhdG
# i:  689 	enzload_id:  ENZLOAD-FASOXST_FWD-fabF
# i:  690 	enzload_id:  ENZLOAD-FASOXST_FWD-fabHA_1281
# i:  691 	enzload_id:  ENZLOAD-FASOXST_FWD-fabHA_2100
# i:  692 	enzload_id:  ENZLOAD-FASOXST_FWD-fabHA_2102
# i:  693 	enzload_id:  ENZLOAD-FASOXST_FWD-pksJL
# i:  694 	enzload_id:  ENZLOAD-FATPase_FWD-atpABCDEFGH
# i:  695 	enzload_id:  ENZLOAD-FBA_FWD-fbaA_0238
# i:  696 	enzload_id:  ENZLOAD-FBA_REV-fbaA_0238
# i:  697 	enzload_id:  ENZLOAD-FBA_FWD-fbaA_1875
# i:  698 	enzload_id:  ENZLOAD-FBA_REV-fbaA_1875
# i:  699 	enzload_id:  ENZLOAD-FBA3_FWD-fbaA_1875
# i:  700 	enzload_id:  ENZLOAD-FBA3_REV-fbaA_1875
# i:  702 	enzload_id:  ENZLOAD-FCLPA_FWD-araD
# i:  703 	enzload_id:  ENZLOAD-FDH_FWD-Clo1313_1848
# i:  705 	enzload_id:  ENZLOAD-FE3abc_FWD-fepCCDyvrC
# i:  706 	enzload_id:  ENZLOAD-FGFTh_FWD-purN
# i:  707 	enzload_id:  ENZLOAD-FMNAT_FWD-ribC
# i:  708 	enzload_id:  ENZLOAD-FNOR_FWD-pyrK
# i:  712 	enzload_id:  ENZLOAD-FPGLP_FWD-fbaA
# i:  715 	enzload_id:  ENZLOAD-FRNDPR2r_FWD-pyrK
# i:  716 	enzload_id:  ENZLOAD-FRNDPR2r_REV-pyrK
# i:  717 	enzload_id:  ENZLOAD-FRTT_FWD-ispA
# i:  718 	enzload_id:  ENZLOAD-FRTT_REV-ispA
# i:  719 	enzload_id:  ENZLOAD-FRUabc_FWD-MSTS_0
# i:  720 	enzload_id:  ENZLOAD-FRUabc_FWD-MSTS_1
# i:  721 	enzload_id:  ENZLOAD-FRUabc_FWD-MSTS_2
# i:  722 	enzload_id:  ENZLOAD-FRUabc_FWD-MSTS_3
# i:  723 	enzload_id:  ENZLOAD-FTCL_FWD-folN
# i:  724 	enzload_id:  ENZLOAD-FTHFLi_FWD-fhs
# i:  725 	enzload_id:  ENZLOAD-FUCabc_FWD-MSTS_0
# i:  726 	enzload_id:  ENZLOAD-FUCabc_FWD-MSTS_1
# i:  727 	enzload_id:  ENZLOAD-FUCabc_FWD-MSTS_2
# i:  728 	enzload_id:  ENZLOAD-FUCabc_FWD-MSTS_3
# i:  729 	enzload_id:  ENZLOAD-FUM_FWD-ADU73720_73721
# i:  730 	enzload_id:  ENZLOAD-FUM_REV-ADU73720_73721
# i:  734 	enzload_id:  ENZLOAD-G1PACT_FWD-glmU
# i:  735 	enzload_id:  ENZLOAD-G1PCTYT_FWD-spmH
# i:  736 	enzload_id:  ENZLOAD-G1SAT_FWD-hemL
# i:  737 	enzload_id:  ENZLOAD-G1SAT_REV-hemL
# i:  739 	enzload_id:  ENZLOAD-G3PD1ir_FWD-gpsA
# i:  740 	enzload_id:  ENZLOAD-G3PD2_FWD-gpsA
# i:  743 	enzload_id:  ENZLOAD-G5SD_FWD-proA
# i:  744 	enzload_id:  ENZLOAD-GALAS_FWD-ltaSC_2059
# i:  745 	enzload_id:  ENZLOAD-GALAS_FWD-ltaSC_2170
# i:  746 	enzload_id:  ENZLOAD-GALU_FWD-galU
# i:  747 	enzload_id:  ENZLOAD-GALU_REV-galU
# i:  748 	enzload_id:  ENZLOAD-GAPD_FWD-gapA
# i:  749 	enzload_id:  ENZLOAD-GAPD_REV-gapA
# i:  750 	enzload_id:  ENZLOAD-GARFT_FWD-purN
# i:  756 	enzload_id:  ENZLOAD-GF6PTA_FWD-glmS
# i:  759 	enzload_id:  ENZLOAD-GGT_FWD-dgcK_1339
# i:  760 	enzload_id:  ENZLOAD-GGT_REV-dgcK_1339
# i:  761 	enzload_id:  ENZLOAD-GGT_FWD-dgcK_2103
# i:  762 	enzload_id:  ENZLOAD-GGT_REV-dgcK_2103
# i:  763 	enzload_id:  ENZLOAD-GGT_FWD-dgcKW
# i:  764 	enzload_id:  ENZLOAD-GGT_REV-dgcKW
# i:  765 	enzload_id:  ENZLOAD-GGT_FWD-dgcP_2091
# i:  766 	enzload_id:  ENZLOAD-GGT_REV-dgcP_2091
# i:  767 	enzload_id:  ENZLOAD-GGT_FWD-dgcP_2852
# i:  768 	enzload_id:  ENZLOAD-GGT_REV-dgcP_2852
# i:  769 	enzload_id:  ENZLOAD-GGT_FWD-walR
# i:  770 	enzload_id:  ENZLOAD-GGT_REV-walR
# i:  771 	enzload_id:  ENZLOAD-GHMT2r_FWD-glyA
# i:  772 	enzload_id:  ENZLOAD-GHMT2r_REV-glyA
# i:  773 	enzload_id:  ENZLOAD-GK1_FWD-gmk
# i:  774 	enzload_id:  ENZLOAD-GK1_REV-gmk
# i:  775 	enzload_id:  ENZLOAD-GLAS_FWD-ltaSC_2059
# i:  776 	enzload_id:  ENZLOAD-GLAS_FWD-ltaSC_2170
# i:  777 	enzload_id:  ENZLOAD-GLCabc_FWD-MSTS_0
# i:  778 	enzload_id:  ENZLOAD-GLCabc_FWD-MSTS_1
# i:  779 	enzload_id:  ENZLOAD-GLCabc_FWD-MSTS_2
# i:  780 	enzload_id:  ENZLOAD-GLCabc_FWD-MSTS_3
# i:  785 	enzload_id:  ENZLOAD-GLCP_FWD-glgP
# i:  786 	enzload_id:  ENZLOAD-GLCS1_FWD-glgA_0974
# i:  787 	enzload_id:  ENZLOAD-GLCS1_FWD-glgA_1947
# i:  788 	enzload_id:  ENZLOAD-GLGC_FWD-glgC
# i:  789 	enzload_id:  ENZLOAD-GLGC_FWD-glgCD
# i:  790 	enzload_id:  ENZLOAD-GLGC_FWD-glgD
# i:  791 	enzload_id:  ENZLOAD-GLNabc_FWD-artPhisMglnQ
# i:  792 	enzload_id:  ENZLOAD-GLNabc_REV-artPhisMglnQ
# i:  793 	enzload_id:  ENZLOAD-GLNS_FWD-glnA_1357
# i:  794 	enzload_id:  ENZLOAD-GLNS_FWD-glnA_2031
# i:  795 	enzload_id:  ENZLOAD-GLNS_FWD-glnA_2038
# i:  796 	enzload_id:  ENZLOAD-GLNS_FWD-glnA_2303
# i:  797 	enzload_id:  ENZLOAD-GLNSP2_FWD-glnA_1357
# i:  798 	enzload_id:  ENZLOAD-GLNSP2_FWD-glnA_2031
# i:  799 	enzload_id:  ENZLOAD-GLNSP2_FWD-glnA_2038
# i:  800 	enzload_id:  ENZLOAD-GLNSP2_FWD-glnA_2303
# i:  801 	enzload_id:  ENZLOAD-GLNTRAT_FWD-gatABC_0
# i:  802 	enzload_id:  ENZLOAD-GLNTRAT_FWD-gatABC_1
# i:  803 	enzload_id:  ENZLOAD-GLNTRS_FWD-gltX
# i:  804 	enzload_id:  ENZLOAD-GLU5K_FWD-proJ
# i:  805 	enzload_id:  ENZLOAD-GLUabc_FWD-artPhisMglnQ
# i:  806 	enzload_id:  ENZLOAD-GLUabc_REV-artPhisMglnQ
# i:  807 	enzload_id:  ENZLOAD-GLUDy_FWD-rocG
# i:  808 	enzload_id:  ENZLOAD-GLUDy_REV-rocG
# i:  809 	enzload_id:  ENZLOAD-GLUN_FWD-ADU74738
# i:  810 	enzload_id:  ENZLOAD-GLUN_FWD-carAB_1267
# i:  811 	enzload_id:  ENZLOAD-GLUN_FWD-carAB_2559
# i:  812 	enzload_id:  ENZLOAD-GLUN_FWD-gltB
# i:  813 	enzload_id:  ENZLOAD-GLUN_FWD-guaA
# i:  814 	enzload_id:  ENZLOAD-GLUN_FWD-hisHF
# i:  815 	enzload_id:  ENZLOAD-GLUN_FWD-murTgatD
# i:  816 	enzload_id:  ENZLOAD-GLUN_FWD-pyrG
# i:  817 	enzload_id:  ENZLOAD-GLUN_REV-ADU74738
# i:  818 	enzload_id:  ENZLOAD-GLUN_REV-carAB_1267
# i:  819 	enzload_id:  ENZLOAD-GLUN_REV-carAB_2559
# i:  820 	enzload_id:  ENZLOAD-GLUN_REV-gltB
# i:  821 	enzload_id:  ENZLOAD-GLUN_REV-guaA
# i:  822 	enzload_id:  ENZLOAD-GLUN_REV-hisHF
# i:  823 	enzload_id:  ENZLOAD-GLUN_REV-murTgatD
# i:  824 	enzload_id:  ENZLOAD-GLUN_REV-pyrG
# i:  825 	enzload_id:  ENZLOAD-GLUPRT_FWD-purF
# i:  826 	enzload_id:  ENZLOAD-GLUR_FWD-rcmE
# i:  827 	enzload_id:  ENZLOAD-GLUR_REV-rcmE
# i:  828 	enzload_id:  ENZLOAD-GLUTAS_FWD-ltaSC_2059
# i:  829 	enzload_id:  ENZLOAD-GLUTAS_FWD-ltaSC_2170
# i:  830 	enzload_id:  ENZLOAD-GLUTRR_FWD-hemA
# i:  831 	enzload_id:  ENZLOAD-GLUTRS_FWD-gltX
# i:  832 	enzload_id:  ENZLOAD-GLYALDDr_FWD-aldX
# i:  833 	enzload_id:  ENZLOAD-GLYALDDr_REV-aldX
# i:  834 	enzload_id:  ENZLOAD-GLYAT_FWD-bioF
# i:  835 	enzload_id:  ENZLOAD-GLYAT_REV-bioF
# i:  837 	enzload_id:  ENZLOAD-GLYCK2_FWD-glxK
# i:  838 	enzload_id:  ENZLOAD-GLYCL_FWD-cspD
# i:  839 	enzload_id:  ENZLOAD-GLYCL_FWD-glyA
# i:  840 	enzload_id:  ENZLOAD-GLYCL_FWD-trpAB
# i:  841 	enzload_id:  ENZLOAD-GLYCLTDx_FWD-yvcT
# i:  842 	enzload_id:  ENZLOAD-GLYCLTDx_REV-yvcT
# i:  843 	enzload_id:  ENZLOAD-GLYHMT_FWD-glyA
# i:  844 	enzload_id:  ENZLOAD-GLYHMT_REV-glyA
# i:  845 	enzload_id:  ENZLOAD-GLYK_FWD-glpK
# i:  846 	enzload_id:  ENZLOAD-GLYPT_FWD-glxK
# i:  847 	enzload_id:  ENZLOAD-GLYt_FWD-azlCD
# i:  848 	enzload_id:  ENZLOAD-GLYt_REV-azlCD
# i:  849 	enzload_id:  ENZLOAD-GLYTA_FWD-pucG
# i:  850 	enzload_id:  ENZLOAD-GLYTA_REV-pucG
# i:  851 	enzload_id:  ENZLOAD-GLYTAS_FWD-ltaSC_2059
# i:  852 	enzload_id:  ENZLOAD-GLYTAS_FWD-ltaSC_2170
# i:  853 	enzload_id:  ENZLOAD-GLYTRS_FWD-ADU74012
# i:  854 	enzload_id:  ENZLOAD-GMAND_FWD-ytcB
# i:  855 	enzload_id:  ENZLOAD-GMAND_REV-ytcB
# i:  856 	enzload_id:  ENZLOAD-GMPS_FWD-guaA
# i:  857 	enzload_id:  ENZLOAD-GMPS2_FWD-guaA
# i:  858 	enzload_id:  ENZLOAD-GPAR_FWD-apt
# i:  859 	enzload_id:  ENZLOAD-GPAR_FWD-hptA
# ...
# i:  1388 	enzload_id:  ENZLOAD-PUNP1_REV-pupG_1056
# i:  1389 	enzload_id:  ENZLOAD-PUNP1_FWD-ylmD
# i:  1390 	enzload_id:  ENZLOAD-PUNP1_REV-ylmD
# i:  1391 	enzload_id:  ENZLOAD-PUNP2_FWD-deoD
# i:  1392 	enzload_id:  ENZLOAD-PUNP2_REV-deoD
# i:  1393 	enzload_id:  ENZLOAD-PUNP2_FWD-pupG_1056
# i:  1394 	enzload_id:  ENZLOAD-PUNP2_REV-pupG_1056
# i:  1395 	enzload_id:  ENZLOAD-PUNP2_FWD-ylmD
# i:  1396 	enzload_id:  ENZLOAD-PUNP2_REV-ylmD
# i:  1397 	enzload_id:  ENZLOAD-PUNP3_FWD-deoD
# i:  1398 	enzload_id:  ENZLOAD-PUNP3_REV-deoD
# i:  1399 	enzload_id:  ENZLOAD-PUNP3_FWD-pupG_1056
# i:  1400 	enzload_id:  ENZLOAD-PUNP3_REV-pupG_1056
# i:  1401 	enzload_id:  ENZLOAD-PUNP3_FWD-ylmD
# i:  1402 	enzload_id:  ENZLOAD-PUNP3_REV-ylmD
# i:  1403 	enzload_id:  ENZLOAD-PUNP4_FWD-deoD
# i:  1404 	enzload_id:  ENZLOAD-PUNP4_REV-deoD
# i:  1405 	enzload_id:  ENZLOAD-PUNP4_FWD-pupG_1056
# i:  1406 	enzload_id:  ENZLOAD-PUNP4_REV-pupG_1056
# i:  1407 	enzload_id:  ENZLOAD-PUNP4_FWD-ylmD
# i:  1408 	enzload_id:  ENZLOAD-PUNP4_REV-ylmD
# i:  1409 	enzload_id:  ENZLOAD-PUNP5_FWD-deoD
# i:  1410 	enzload_id:  ENZLOAD-PUNP5_REV-deoD
# i:  1411 	enzload_id:  ENZLOAD-PUNP5_FWD-pupG_1056
# i:  1412 	enzload_id:  ENZLOAD-PUNP5_REV-pupG_1056
# i:  1413 	enzload_id:  ENZLOAD-PUNP5_FWD-ylmD
# i:  1414 	enzload_id:  ENZLOAD-PUNP5_REV-ylmD
# i:  1415 	enzload_id:  ENZLOAD-PUNP6_FWD-deoD
# i:  1416 	enzload_id:  ENZLOAD-PUNP6_REV-deoD
# i:  1417 	enzload_id:  ENZLOAD-PUNP6_FWD-pupG_1056
# i:  1418 	enzload_id:  ENZLOAD-PUNP6_REV-pupG_1056
# i:  1419 	enzload_id:  ENZLOAD-PUNP6_FWD-ylmD
# i:  1420 	enzload_id:  ENZLOAD-PUNP6_REV-ylmD
# i:  1421 	enzload_id:  ENZLOAD-PUNP7_FWD-deoD
# i:  1422 	enzload_id:  ENZLOAD-PUNP7_REV-deoD
# i:  1423 	enzload_id:  ENZLOAD-PUNP7_FWD-pupG_1056
# i:  1424 	enzload_id:  ENZLOAD-PUNP7_REV-pupG_1056
# i:  1425 	enzload_id:  ENZLOAD-PUNP7_FWD-ylmD
# i:  1426 	enzload_id:  ENZLOAD-PUNP7_REV-ylmD
# i:  1427 	enzload_id:  ENZLOAD-PYLALDOX_FWD-aldX
# i:  1428 	enzload_id:  ENZLOAD-PYLALDOX_REV-aldX
# i:  1429 	enzload_id:  ENZLOAD-PYNP1_FWD-pdp
# i:  1430 	enzload_id:  ENZLOAD-PYNP1_REV-pdp
# i:  1431 	enzload_id:  ENZLOAD-PYNP2r_FWD-pdp
# i:  1432 	enzload_id:  ENZLOAD-PYNP2r_REV-pdp
# i:  1438 	enzload_id:  ENZLOAD-QUINDH_FWD-aroE
# i:  1439 	enzload_id:  ENZLOAD-QULNS_FWD-nadA
# i:  1440 	enzload_id:  ENZLOAD-QUOR_FWD-aroE
# i:  1441 	enzload_id:  ENZLOAD-R00182_FWD-alkA
# i:  1442 	enzload_id:  ENZLOAD-R00182_REV-alkA
# i:  1443 	enzload_id:  ENZLOAD-R02135_FWD-rsgA_1662
# i:  1444 	enzload_id:  ENZLOAD-R02135_REV-rsgA_1662
# i:  1445 	enzload_id:  ENZLOAD-R02135_FWD-rsgA_2278
# i:  1446 	enzload_id:  ENZLOAD-R02135_REV-rsgA_2278
# i:  1447 	enzload_id:  ENZLOAD-R03004_FWD-mazG_0245
# i:  1448 	enzload_id:  ENZLOAD-R03004_FWD-mazG_0083
# i:  1449 	enzload_id:  ENZLOAD-R03036_FWD-mazG_0245
# i:  1450 	enzload_id:  ENZLOAD-R03036_FWD-mazG_0083
# i:  1451 	enzload_id:  ENZLOAD-R03105_FWD-mccB
# i:  1452 	enzload_id:  ENZLOAD-R03472_FWD-thiC
# i:  1453 	enzload_id:  ENZLOAD-R03472_REV-thiC
# i:  1454 	enzload_id:  ENZLOAD-R04399_FWD-capD_0239
# i:  1455 	enzload_id:  ENZLOAD-R04399_REV-capD_0239
# i:  1456 	enzload_id:  ENZLOAD-R04399_FWD-capD_2905
# i:  1457 	enzload_id:  ENZLOAD-R04399_REV-capD_2905
# i:  1458 	enzload_id:  ENZLOAD-R04399_FWD-flaA
# i:  1459 	enzload_id:  ENZLOAD-R04399_REV-flaA
# i:  1460 	enzload_id:  ENZLOAD-R05046_FWD-folE
# i:  1461 	enzload_id:  ENZLOAD-R05602_FWD-capD_0239
# i:  1462 	enzload_id:  ENZLOAD-R05602_REV-capD_0239
# i:  1463 	enzload_id:  ENZLOAD-R05602_FWD-capD_2905
# i:  1464 	enzload_id:  ENZLOAD-R05602_REV-capD_2905
# i:  1465 	enzload_id:  ENZLOAD-R05602_FWD-flaA
# i:  1466 	enzload_id:  ENZLOAD-R05602_REV-flaA
# i:  1467 	enzload_id:  ENZLOAD-R07459_FWD-thiF
# i:  1468 	enzload_id:  ENZLOAD-R07460_FWD-nifS_1150
# i:  1469 	enzload_id:  ENZLOAD-R07460_FWD-nifS_1503
# i:  1470 	enzload_id:  ENZLOAD-R07461_FWD-thiI
# i:  1471 	enzload_id:  ENZLOAD-R09543_FWD-ydaC
# i:  1472 	enzload_id:  ENZLOAD-R09543_REV-ydaC
# i:  1474 	enzload_id:  ENZLOAD-R10115_FWD-fabF
# i:  1475 	enzload_id:  ENZLOAD-R10116_FWD-fabG_1283
# i:  1476 	enzload_id:  ENZLOAD-R10116_REV-fabG_1283
# i:  1477 	enzload_id:  ENZLOAD-R10117_FWD-fabG_2272
# i:  1478 	enzload_id:  ENZLOAD-R10117_REV-fabG_2272
# i:  1479 	enzload_id:  ENZLOAD-R10118_FWD-fabI
# i:  1480 	enzload_id:  ENZLOAD-R10118_REV-fabI
# i:  1481 	enzload_id:  ENZLOAD-R10119_FWD-fabF
# i:  1482 	enzload_id:  ENZLOAD-R10120_FWD-fabG_1283
# i:  1483 	enzload_id:  ENZLOAD-R10120_REV-fabG_1283
# i:  1484 	enzload_id:  ENZLOAD-R10121_FWD-fabZ
# i:  1485 	enzload_id:  ENZLOAD-R10121_REV-fabZ
# i:  1486 	enzload_id:  ENZLOAD-R10122_FWD-fabI
# i:  1487 	enzload_id:  ENZLOAD-R10122_REV-fabI
# i:  1488 	enzload_id:  ENZLOAD-R10246_FWD-hydG
# i:  1489 	enzload_id:  ENZLOAD-R10246_FWD-thiH
# i:  1490 	enzload_id:  ENZLOAD-R10247_FWD-thiG
# i:  1491 	enzload_id:  ENZLOAD-R10712_FWD-thiE
# i:  1492 	enzload_id:  ENZLOAD-R11098_FWD-ridA
# i:  1493 	enzload_id:  ENZLOAD-R11099_FWD-ridA
# i:  1494 	enzload_id:  ENZLOAD-R11633_FWD-ADU74641
# i:  1495 	enzload_id:  ENZLOAD-R11634_FWD-ADU74641
# i:  1496 	enzload_id:  ENZLOAD-R11635_FWD-ADU74641
# i:  1497 	enzload_id:  ENZLOAD-R11636_FWD-ADU74641
# i:  1498 	enzload_id:  ENZLOAD-RBFK_FWD-lgt
# i:  1499 	enzload_id:  ENZLOAD-RBFK_FWD-ribC
# i:  1500 	enzload_id:  ENZLOAD-RBFSb_FWD-ribE
# i:  1501 	enzload_id:  ENZLOAD-RDXR_FWD-nasD
# i:  1502 	enzload_id:  ENZLOAD-RDXR_REV-nasD
# i:  1503 	enzload_id:  ENZLOAD-RE0581R_FWD-fabG_1283
# i:  1504 	enzload_id:  ENZLOAD-RE0581R_FWD-fabG_2272
# i:  1505 	enzload_id:  ENZLOAD-RIBabc_FWD-rbsABC_0
# i:  1506 	enzload_id:  ENZLOAD-RIBabc_REV-rbsABC_0
# i:  1507 	enzload_id:  ENZLOAD-RIBabc_FWD-rbsABC_1
# i:  1508 	enzload_id:  ENZLOAD-RIBabc_REV-rbsABC_1
# i:  1509 	enzload_id:  ENZLOAD-RIBFLVecf_FWD-ecfABT
# i:  1510 	enzload_id:  ENZLOAD-RIBFLVecf_REV-ecfABT
# i:  1511 	enzload_id:  ENZLOAD-RNDR1n_FWD-nrdE
# i:  1512 	enzload_id:  ENZLOAD-RNDR2_FWD-nrdE
# i:  1513 	enzload_id:  ENZLOAD-RNDR3_FWD-nrdE
# i:  1514 	enzload_id:  ENZLOAD-RNDR4_FWD-nrdE
# i:  1515 	enzload_id:  ENZLOAD-RNF_FWD-rnfABCDEG
# i:  1516 	enzload_id:  ENZLOAD-RNF_REV-rnfABCDEG
# i:  1517 	enzload_id:  ENZLOAD-RNMK_FWD-ADU73455
# i:  1518 	enzload_id:  ENZLOAD-RNTR1_FWD-ADU74641
# i:  1519 	enzload_id:  ENZLOAD-RNTR2_FWD-ADU74641
# i:  1520 	enzload_id:  ENZLOAD-RNTR3_FWD-ADU74641
# i:  1521 	enzload_id:  ENZLOAD-RNTR4_FWD-ADU74641
# i:  1522 	enzload_id:  ENZLOAD-RPE_FWD-rpe
# i:  1523 	enzload_id:  ENZLOAD-RPE_REV-rpe
# i:  1524 	enzload_id:  ENZLOAD-RPI_FWD-rpiB
# i:  1525 	enzload_id:  ENZLOAD-RPI_REV-rpiB
# i:  1526 	enzload_id:  ENZLOAD-RPYS_FWD-rbsD
# i:  1527 	enzload_id:  ENZLOAD-RPYS_REV-rbsD
# i:  1528 	enzload_id:  ENZLOAD-rxn27289_FWD-thiGH
# i:  1529 	enzload_id:  ENZLOAD-rxn27289_REV-thiGH
# i:  1530 	enzload_id:  ENZLOAD-rxn27289_FWD-thiGS
# i:  1531 	enzload_id:  ENZLOAD-rxn27289_REV-thiGS
# i:  1532 	enzload_id:  ENZLOAD-rxn44628_FWD-moeB
# i:  1533 	enzload_id:  ENZLOAD-rxn44628_REV-moeB
# i:  1534 	enzload_id:  ENZLOAD-RZ5PP_FWD-phoE_0080
# i:  1535 	enzload_id:  ENZLOAD-RZ5PP_FWD-phoE_0704
# i:  1536 	enzload_id:  ENZLOAD-RZ5PP_FWD-phoE_1271
# i:  1537 	enzload_id:  ENZLOAD-RZ5PP_FWD-phoE_1517
# i:  1538 	enzload_id:  ENZLOAD-SADT_FWD-tufA
# i:  1539 	enzload_id:  ENZLOAD-SADT_FWD-yitB
# i:  1540 	enzload_id:  ENZLOAD-SALCCM_FWD-yrrM
# i:  1541 	enzload_id:  ENZLOAD-SALCCM_REV-yrrM
# i:  1542 	enzload_id:  ENZLOAD-SALMCCOAMT_FWD-yrrM
# i:  1543 	enzload_id:  ENZLOAD-SALMCCOAMT_REV-yrrM
# i:  1544 	enzload_id:  ENZLOAD-SBTabc_FWD-MSTS_0
# i:  1545 	enzload_id:  ENZLOAD-SBTabc_FWD-MSTS_1
# i:  1546 	enzload_id:  ENZLOAD-SBTabc_FWD-MSTS_2
# i:  1547 	enzload_id:  ENZLOAD-SBTabc_FWD-MSTS_3
# i:  1548 	enzload_id:  ENZLOAD-SBTD_D2_FWD-groES
# i:  1549 	enzload_id:  ENZLOAD-SBTD_D2_REV-groES
# i:  1550 	enzload_id:  ENZLOAD-SBTD_D2_FWD-gutB
# i:  1551 	enzload_id:  ENZLOAD-SBTD_D2_REV-gutB
# i:  1552 	enzload_id:  ENZLOAD-SDPTA_FWD-argD
# i:  1553 	enzload_id:  ENZLOAD-SDPTA_REV-argD
# i:  1554 	enzload_id:  ENZLOAD-SERabc_FWD-artPhisMglnQ
# i:  1555 	enzload_id:  ENZLOAD-SERabc_FWD-tycBC
# i:  1556 	enzload_id:  ENZLOAD-SERAT_FWD-cysE
# i:  1557 	enzload_id:  ENZLOAD-SERH_FWD-trpAB_0836
# i:  1558 	enzload_id:  ENZLOAD-SERH_FWD-trpAB_1036
# i:  1559 	enzload_id:  ENZLOAD-SERTRS_FWD-serS
# i:  1560 	enzload_id:  ENZLOAD-SERTRS2_FWD-serS
# i:  1561 	enzload_id:  ENZLOAD-SHCHD2_FWD-Clo1313_0109
# i:  1562 	enzload_id:  ENZLOAD-SHCHF_FWD-sirC
# i:  1563 	enzload_id:  ENZLOAD-SHCHF_REV-sirC
# i:  1564 	enzload_id:  ENZLOAD-SHOR_FWD-aroE
# i:  1565 	enzload_id:  ENZLOAD-SHSL1_FWD-mccB
# i:  1566 	enzload_id:  ENZLOAD-SHSL1_REV-mccB
# i:  1567 	enzload_id:  ENZLOAD-SHSL2_FWD-mccB
# i:  1568 	enzload_id:  ENZLOAD-SHSL4_FWD-mccB
# i:  1569 	enzload_id:  ENZLOAD-SKDH_FWD-Clo1313_1366
# i:  1570 	enzload_id:  ENZLOAD-SKK_FWD-aroK_0068
# i:  1571 	enzload_id:  ENZLOAD-SKK_FWD-aroK_1492
# i:  1572 	enzload_id:  ENZLOAD-SLCYSS_FWD-cysK
# i:  1573 	enzload_id:  ENZLOAD-SLCYSS_FWD-mccA
# i:  1574 	enzload_id:  ENZLOAD-SLCYSS_FWD-mccB
# i:  1575 	enzload_id:  ENZLOAD-SMLSHL_FWD-pnbA
# i:  1576 	enzload_id:  ENZLOAD-SMLSHL_REV-pnbA
# i:  1577 	enzload_id:  ENZLOAD-SPMDabc_FWD-potABCDF
# i:  1578 	enzload_id:  ENZLOAD-SPMS_FWD-speE_2
# i:  1579 	enzload_id:  ENZLOAD-SPMS_FWD-speE_4
# i:  1580 	enzload_id:  ENZLOAD-SPRMS_FWD-speE_2
# i:  1581 	enzload_id:  ENZLOAD-SPRMS_REV-speE_2
# i:  1582 	enzload_id:  ENZLOAD-SPRMS_FWD-speE_4
# i:  1583 	enzload_id:  ENZLOAD-SPRMS_REV-speE_4
# i:  1584 	enzload_id:  ENZLOAD-SULabc_FWD-SbpcysTWmsmX
# i:  1585 	enzload_id:  ENZLOAD-SULabc_FWD-tauABC
# i:  1586 	enzload_id:  ENZLOAD-SULR_ferr_FWD-nasD
# i:  1587 	enzload_id:  ENZLOAD-TBALOR_FWD-aldX
# i:  1588 	enzload_id:  ENZLOAD-TDPDRE_FWD-spsL_0146
# i:  1589 	enzload_id:  ENZLOAD-TDPDRE_FWD-spsL_0887
# i:  1590 	enzload_id:  ENZLOAD-TDPGDH_FWD-spsJ_1127
# i:  1591 	enzload_id:  ENZLOAD-TDPGDH_FWD-spsJ_2893
# i:  1592 	enzload_id:  ENZLOAD-TGBPA_FWD-fbaA
# i:  1593 	enzload_id:  ENZLOAD-THFGLUS_FWD-folC
# i:  1594 	enzload_id:  ENZLOAD-THFOR1_FWD-dfrA
# i:  1595 	enzload_id:  ENZLOAD-THFOR2_FWD-dfrA
# i:  1596 	enzload_id:  ENZLOAD-THFOR2_FWD-dpsA
# i:  1597 	enzload_id:  ENZLOAD-THISAT_FWD-moeB
# i:  1598 	enzload_id:  ENZLOAD-THISAT_FWD-thiF
# i:  1599 	enzload_id:  ENZLOAD-THMecf_FWD-ecfABT
# i:  1600 	enzload_id:  ENZLOAD-THMecf_REV-ecfABT
# i:  1602 	enzload_id:  ENZLOAD-THRabc_FWD-artPhisMglnQ
# i:  1603 	enzload_id:  ENZLOAD-THRabc_FWD-tycBC
# i:  1604 	enzload_id:  ENZLOAD-THRS_FWD-ADU73935
# i:  1605 	enzload_id:  ENZLOAD-THRTRS_FWD-thrS
# i:  1606 	enzload_id:  ENZLOAD-TKT1_FWD-tktA_dxs_1
# i:  1607 	enzload_id:  ENZLOAD-TKT1_REV-tktA_dxs_1
# i:  1608 	enzload_id:  ENZLOAD-TKT1_FWD-tktA_dxs_2
# i:  1609 	enzload_id:  ENZLOAD-TKT1_REV-tktA_dxs_2
# i:  1610 	enzload_id:  ENZLOAD-TKT2_FWD-tktA_dxs_1
# i:  1611 	enzload_id:  ENZLOAD-TKT2_REV-tktA_dxs_1
# i:  1612 	enzload_id:  ENZLOAD-TKT2_FWD-tktA_dxs_2
# i:  1613 	enzload_id:  ENZLOAD-TKT2_REV-tktA_dxs_2
# i:  1614 	enzload_id:  ENZLOAD-TMAMT_FWD-ADU73462
# i:  1615 	enzload_id:  ENZLOAD-TMAMT_REV-ADU73462
# i:  1616 	enzload_id:  ENZLOAD-TMAMT_FWD-ADU73463
# i:  1617 	enzload_id:  ENZLOAD-TMAMT_REV-ADU73463
# i:  1618 	enzload_id:  ENZLOAD-TMAMT_FWD-ADU73464
# i:  1619 	enzload_id:  ENZLOAD-TMAMT_REV-ADU73464
# i:  1620 	enzload_id:  ENZLOAD-TMDPK_FWD-thiN
# i:  1623 	enzload_id:  ENZLOAD-TMDPPK_FWD-thiN
# i:  1624 	enzload_id:  ENZLOAD-TMDS_FWD-thyA
# i:  1625 	enzload_id:  ENZLOAD-TMIPDCOAL_FWD-grsT
# i:  1626 	enzload_id:  ENZLOAD-TMIPDCOAL_FWD-lcfA
# i:  1627 	enzload_id:  ENZLOAD-TMIPDCOAL_FWD-lcfB
# i:  1628 	enzload_id:  ENZLOAD-TMIPDCOAL_FWD-ldeI
# i:  1629 	enzload_id:  ENZLOAD-TPI_FWD-tpiA
# i:  1630 	enzload_id:  ENZLOAD-TPI_REV-tpiA
# i:  1631 	enzload_id:  ENZLOAD-TRDR_FWD-trxB_2617
# i:  1632 	enzload_id:  ENZLOAD-TRDR_FWD-trxB_2618
# i:  1634 	enzload_id:  ENZLOAD-TRNAATPAT_FWD-nrnA
# i:  1635 	enzload_id:  ENZLOAD-TRNAATPAT_FWD-pcnB
# i:  1636 	enzload_id:  ENZLOAD-TRNACCAT_FWD-nrnA
# i:  1637 	enzload_id:  ENZLOAD-TRNACCAT_FWD-pcnB
# i:  1638 	enzload_id:  ENZLOAD-TRNACTPAT_FWD-nrnA
# i:  1639 	enzload_id:  ENZLOAD-TRNACTPAT_FWD-pcnB
# i:  1640 	enzload_id:  ENZLOAD-TRNACTPAT2_FWD-nrnA
# i:  1641 	enzload_id:  ENZLOAD-TRNACTPAT2_FWD-pcnB
# i:  1643 	enzload_id:  ENZLOAD-TRPabc_FWD-artPhisMglnQ
# i:  1644 	enzload_id:  ENZLOAD-TRPabc_FWD-tycBC
# i:  1645 	enzload_id:  ENZLOAD-TRPS2_FWD-tryAB_0836
# i:  1646 	enzload_id:  ENZLOAD-TRPS2_FWD-tryAB_1036
# i:  1647 	enzload_id:  ENZLOAD-TRPS3_FWD-trpAB
# i:  1648 	enzload_id:  ENZLOAD-TRPTRS_FWD-trpS
# i:  1649 	enzload_id:  ENZLOAD-TYHMDabc_FWD-nupOPQ
# i:  1650 	enzload_id:  ENZLOAD-TYHMDabc_REV-nupOPQ
# i:  1651 	enzload_id:  ENZLOAD-TYRabc_FWD-artPhisMglnQ
# i:  1652 	enzload_id:  ENZLOAD-TYRabc_FWD-tycBC
# i:  1653 	enzload_id:  ENZLOAD-TYRTA_FWD-aspB
# i:  1654 	enzload_id:  ENZLOAD-TYRTA_REV-aspB
# i:  1655 	enzload_id:  ENZLOAD-TYRTA_FWD-hisC_0424
# i:  1656 	enzload_id:  ENZLOAD-TYRTA_REV-hisC_0424
# i:  1657 	enzload_id:  ENZLOAD-TYRTA_FWD-hisC_1619
# i:  1658 	enzload_id:  ENZLOAD-TYRTA_REV-hisC_1619
# i:  1659 	enzload_id:  ENZLOAD-TYRTA_FWD-yhdR
# i:  1660 	enzload_id:  ENZLOAD-TYRTA_REV-yhdR
# i:  1661 	enzload_id:  ENZLOAD-TYRTRS_FWD-tyrS
# i:  1662 	enzload_id:  ENZLOAD-UAAGDS_FWD-murE
# i:  1664 	enzload_id:  ENZLOAD-UACMUOR_FWD-murB
# i:  1665 	enzload_id:  ENZLOAD-UAG2E_FWD-mnaA_0188
# i:  1666 	enzload_id:  ENZLOAD-UAG2EMA_FWD-mnaA_0188
# i:  1667 	enzload_id:  ENZLOAD-UAG2EMA_FWD-mnaA_0229
# i:  1668 	enzload_id:  ENZLOAD-UAG4Ei_FWD-galE
# i:  1669 	enzload_id:  ENZLOAD-UAG4Ei_FWD-spmG_0144
# i:  1670 	enzload_id:  ENZLOAD-UAG4Ei_FWD-spmG_0234
# i:  1671 	enzload_id:  ENZLOAD-UAG4Ei_FWD-spsJ
# i:  1672 	enzload_id:  ENZLOAD-UAGCVT_FWD-murA
# i:  1673 	enzload_id:  ENZLOAD-UAGCVT_FWD-murAA
# i:  1674 	enzload_id:  ENZLOAD-UAGCVT_FWD-murAB
# i:  1675 	enzload_id:  ENZLOAD-UAGDH_FWD-tuaD
# i:  1676 	enzload_id:  ENZLOAD-UAGDH_REV-tuaD
# i:  1677 	enzload_id:  ENZLOAD-UAGP2UAG_FWD-glmU
# i:  1678 	enzload_id:  ENZLOAD-UAGPT2_FWD-murG
# i:  1679 	enzload_id:  ENZLOAD-UAGPT3_FWD-murG
# i:  1680 	enzload_id:  ENZLOAD-UAMAGS_FWD-murD
# i:  1681 	enzload_id:  ENZLOAD-UAMAS_FWD-murC
# i:  1682 	enzload_id:  ENZLOAD-UAPGR_FWD-murB
# i:  1683 	enzload_id:  ENZLOAD-UDCP_FWD-mraY
# i:  1684 	enzload_id:  ENZLOAD-UDCPDPS_FWD-uppS
# i:  1685 	enzload_id:  ENZLOAD-UDCPT_FWD-mraY
# i:  1686 	enzload_id:  ENZLOAD-UDPG2DGT_FWD-Clo1313_0728
# i:  1687 	enzload_id:  ENZLOAD-UDPGD_FWD-tuaD
# i:  1689 	enzload_id:  ENZLOAD-UDPGP_FWD-mazG_0245
# i:  1690 	enzload_id:  ENZLOAD-UDPGP_FWD-mazG_0083
# i:  1691 	enzload_id:  ENZLOAD-UDPKAAT_FWD-spsC
# i:  1693 	enzload_id:  ENZLOAD-UGE2_FWD-ytcB_0892
# i:  1694 	enzload_id:  ENZLOAD-UGE2_REV-ytcB_0892
# i:  1695 	enzload_id:  ENZLOAD-UGE2_FWD-ytcB_1999
# i:  1696 	enzload_id:  ENZLOAD-UGE2_REV-ytcB_1999
# i:  1697 	enzload_id:  ENZLOAD-UGLDDS2_FWD-murF
# i:  1698 	enzload_id:  ENZLOAD-UGMDDS_FWD-murF
# i:  1699 	enzload_id:  ENZLOAD-UMPK_FWD-pyrH
# i:  1700 	enzload_id:  ENZLOAD-UMPK_REV-pyrH
# i:  1701 	enzload_id:  ENZLOAD-UPP3MT_FWD-nasF
# i:  1702 	enzload_id:  ENZLOAD-UPP3S_1_FWD-nasF
# i:  1703 	enzload_id:  ENZLOAD-UPPPHL_FWD-uppP
# i:  1704 	enzload_id:  ENZLOAD-UPPRT_FWD-pyrR_2
# i:  1705 	enzload_id:  ENZLOAD-UPPRT_FWD-pyrR_6
# i:  1706 	enzload_id:  ENZLOAD-UPPRT_FWD-upp
# i:  1707 	enzload_id:  ENZLOAD-UREA_FWD-ureABC
# i:  1708 	enzload_id:  ENZLOAD-UREAabc_FWD-urtABCDE
# i:  1709 	enzload_id:  ENZLOAD-URIabc_FWD-nupOPQ
# i:  1710 	enzload_id:  ENZLOAD-URIabc_REV-nupOPQ
# i:  1711 	enzload_id:  ENZLOAD-URIDK2r_FWD-Tmk
# i:  1712 	enzload_id:  ENZLOAD-URIDK2r_REV-Tmk
# i:  1713 	enzload_id:  ENZLOAD-URIK1_FWD-thrS
# i:  1714 	enzload_id:  ENZLOAD-URIK2_FWD-thrS
# i:  1715 	enzload_id:  ENZLOAD-URIK3_FWD-thrS
# i:  1716 	enzload_id:  ENZLOAD-UTCY_FWD-thrS
# i:  1717 	enzload_id:  ENZLOAD-UTUP_FWD-thrS
# i:  1718 	enzload_id:  ENZLOAD-VALt_FWD-azlCD
# i:  1719 	enzload_id:  ENZLOAD-VALt_REV-azlCD
# i:  1720 	enzload_id:  ENZLOAD-VALTA_FWD-ivlK
# i:  1721 	enzload_id:  ENZLOAD-VALTA_REV-ivlK
# i:  1722 	enzload_id:  ENZLOAD-VALTRS_FWD-valS
# i:  1723 	enzload_id:  ENZLOAD-vATPS_FWD-vatpABCDEFGHIK
# i:  1724 	enzload_id:  ENZLOAD-VOR1b_FWD-Clo1313_1354
# i:  1725 	enzload_id:  ENZLOAD-VOR2b_FWD-VorABCD
# i:  1726 	enzload_id:  ENZLOAD-VOR3b_FWD-Clo1313_1354
# i:  1727 	enzload_id:  ENZLOAD-XPPT_FWD-hprT
# i:  1728 	enzload_id:  ENZLOAD-XPPT_REV-hprT
# i:  1731 	enzload_id:  ENZLOAD-XYLTD_D_FWD-gutB
# i:  1738 	enzload_id:  ENZLOAD-ZNabc_FWD-znuABC

# %% [markdown]
# #### Build files related to MW

# %%
#build the pro_mw_g_per_mmol.txt file

data = getattr(df_pro,'MW (g/mmol)').to_dict()
ids = getattr(df_pro,'id').to_list()

#build the string to write
prot_mw_str = ""

#for each id
for id in ids:
    
    new_line = id + "\t" + str(data[id]) + "\n"

    #for debugging, comment out if unused
    #print(new_line)

    prot_mw_str = prot_mw_str + new_line

#write to output
with open('./'+def_out+'/pro_mw_g_per_mmol.txt', 'w') as f:
    f.write(prot_mw_str)

# %%
#get MW list
mw_list = getattr(df_enz,"MW (g/mmol)").to_list()

#get enz list
enz_list = getattr(df_enz,"enz").to_list()

#create string for writing output file
enz_mw_str = "enz_id\tMW (g/mmol)\n"

#add to the string for enzyme entries
#need to initialize a counter
c = 0

#list to keep track of existing entries
#predefined values prevent adding unknown
existing_pro = ['nan','unknown']

for enz in enz_list:

    #only add a new line if unique entry
    if not(str(enz) in existing_pro):

        #for debugging, comment out if unused
        #print("enz: |",enz,"|, type: ",type(enz))
    
        new_line = str(enz) + "\t" + str(mw_list[c]) + "\n"

        #for debugging, comment out if unused
        #print(new_line)

        enz_mw_str = enz_mw_str + new_line

        existing_pro.append(enz)

    c = c + 1

#write to output
with open('./'+def_out+'/enz_mw_g_per_mmol_norxnmapped.txt', 'w') as f:
    f.write(enz_mw_str)

# %% [markdown]
# #### Protein file

# %%
### Protein

#stores protein lengths
pro_lengths = {}

c = df_eqn.shape[0] - 1

for i in df_pro.index:  

    c += 1

    #for debugging, comment out if not using
    #print(i)

    prot_st = OrderedDict()

    for met in ['MET-atp_c', 'MET-h2o_c',
                'MET-adp_c', 'MET-pi_c', 'MET-h_c', 'MET-gtp_c',
                'MET-gdp_c']:
        prot_st[met] = 0

    seq = df_pro.sequence[i][:-1]

    #added code to get protein lengths
    pro_lengths[i] = len(seq) - 1

    #for debugging, comment out when not using
    #print("i: ",i,"\tlen: ",pro_lengths[i])

    #print("seq: ",seq)

    #build trna stoich for protein synthesis
    for aa in df_aamap.index:

        #for debugging comment out if unused
        #print("aa: ",aa,"\tcount: ",seq.count(aa))

        prot_st[df_aamap.tRNA_in[aa]] = -seq.count(aa)
        prot_st[df_aamap.tRNA_out[aa]] = seq.count(aa)
        
    cofs_str = df_pro.cofactor_stoich[i]
    if pd.isnull(cofs_str) == False:

        #for debugging, comment out when not used
        print("protein: ",i,"\tcofacs: |",cofs_str,"|")

        cofs_st = cofs_str.split(',')
        cofs_st = OrderedDict({c.split(':')[0]:c.split(':')[1] for c in cofs_st})
        for k,v in cofs_st.items():
            prot_st['MET-' + k] = -int(v)
                
    prot_st['PRO-' + df_pro.id[i]] = 1
    
    df_eqn.loc[c, 'coupling_type'] = 'prot_ribo'
    df_eqn.loc[c, 'coupling_species'] = 'ribo'
        
    # Set protein to occupy cellular space in cytosol
    prot_st['BIO-protcyt'] = df_pro.loc[i, 'MW (g/mmol)']
    
    # Cost: Initiation: 1 ATP + 2 GTP (initiate and bind Methionine)
    # Elongation: 2 GTP / cycle
    # (elongation process excludes Methionine since it is already bound in initiation process)
    for met in ['MET-atp_c', 'MET-h2o_c']:
        prot_st[met] -= 1
    for met in ['MET-adp_c', 'MET-pi_c', 'MET-h_c']:
        prot_st[met] += 1
                
    for met in ['MET-gtp_c', 'MET-h2o_c']:
        prot_st[met] -= 2*len(seq)
    for met in ['MET-gdp_c', 'MET-pi_c', 'MET-h_c']:
        prot_st[met] += 2*len(seq)
    
    df_eqn.loc[c, 'id'] = 'PROSYN-' + df_pro.id[i]
    df_eqn.loc[c, 'type'] = 'protein'
    df_eqn.loc[c, 'reaction'] = build_reaction_equation_from_metabolites_dict_RBA(prot_st, arrow='-->')

#write the protein length file
len_str = "/\n"

for prot in pro_lengths:

    new_line = "'PROSYN-" + prot + "' " + str(pro_lengths[prot]) + "\n"

    #for debugging, comment out if unused
    #print(new_line)

    len_str = len_str + new_line

#finally, add in the dummy
len_str = len_str + "'PROSYN-PROTDUMMY' "+str(dummy_length)+"\n"

len_str = len_str + "/"

with open('./'+def_out+'/RBA_proteinLength.txt', 'w') as f:
    f.write(len_str)
    
### Dummy protein
prot_st = OrderedDict()
for met in ['MET-atp_c', 'MET-h2o_c',
            'MET-adp_c', 'MET-pi_c', 'MET-h_c', 'MET-gtp_c',
            'MET-gdp_c']:
    prot_st[met] = 0

seq = df_pro.sequence[i][:-1]
for aa in df_aamap.index:
    prot_st[df_aamap.tRNA_in[aa]] = -round(df_aa_dummy.N_AA[aa], 4)
    prot_st[df_aamap.tRNA_out[aa]] = round(df_aa_dummy.N_AA[aa], 4)

for met in ['MET-atp_c', 'MET-h2o_c']:
    prot_st[met] -= 1
for met in ['MET-adp_c', 'MET-pi_c', 'MET-h_c']:
    prot_st[met] += 1

for met in ['MET-gtp_c', 'MET-h2o_c']:
    prot_st[met] -= 2*dummy_medianL
for met in ['MET-gdp_c', 'MET-pi_c', 'MET-h_c']:
    prot_st[met] += 2*dummy_medianL

c += 1
prot_st['BIO-protdummy'] = dummy_MW
df_eqn.loc[c, 'id'] = 'PROSYN-PROTDUMMY'
df_eqn.loc[c, 'coupling_type'] = 'prot_ribo'
df_eqn.loc[c, 'coupling_species'] = 'ribo'
df_eqn.loc[c, 'type'] = 'protein'
df_eqn.loc[c, 'reaction'] = build_reaction_equation_from_metabolites_dict_RBA(prot_st,
                                                        arrow='-->', floatdecimal=6)
# Protein waste reactions
c = df_eqn.shape[0] - 1
for i in df_pro.index:     
    c += 1
    prot_st = OrderedDict()
    prot_st['PRO-' + df_pro.id[i]] = -1
    
    df_eqn.loc[c, 'id'] = 'PROWASTE-' + df_pro.id[i]
    df_eqn.loc[c, 'type'] = 'proteinWaste'
    df_eqn.loc[c, 'reaction'] = build_reaction_equation_from_metabolites_dict_RBA(prot_st, arrow='-->')
    
### Biomass
for i in df_biom.index:
    c += 1
    df_eqn.loc[c, 'id'] = df_biom.rxn_id[i]
    df_eqn.loc[c, 'type'] = 'biomass'
    df_eqn.loc[c, 'reaction'] = df_biom.rxn_equation[i]
# Out:
# protein:  Clo1313_0021 	cofacs: | 4fe4s_c:1 |
# protein:  Clo1313_0061 	cofacs: | fmn_c:1,4fe4s_c:2 |
# protein:  Clo1313_0062 	cofacs: | fmn_c:1 |
# protein:  Clo1313_0063 	cofacs: | fmn_c:1 |
# protein:  Clo1313_0066 	cofacs: | 4fe4s_c:3 |
# protein:  Clo1313_0068 	cofacs: | mg2_c:1 |
# protein:  Clo1313_0076 	cofacs: | zn2_c:1 |
# protein:  Clo1313_0098 	cofacs: | zn2_c:1 |
# protein:  Clo1313_0099 	cofacs: | mg2_c:1 |
# protein:  Clo1313_0101 	cofacs: | mg2_c:2 |
# protein:  Clo1313_0113 	cofacs: | pydx5p_c:1 |
# protein:  Clo1313_0118 	cofacs: | 4fe4s_c:1 |
# protein:  Clo1313_0124 	cofacs: | 4fe4s_c:1 |
# protein:  Clo1313_0137 	cofacs: | 4fe4s_c:1 |
# protein:  Clo1313_0138 	cofacs: | 4fe4s_c:1 |
# protein:  Clo1313_0139 	cofacs: | 4fe4s_c:1 |
# protein:  Clo1313_0142 	cofacs: | 4fe4s_c:1 |
# protein:  Clo1313_0152 	cofacs: | 4fe4s_c:1 |
# protein:  Clo1313_0175 	cofacs: | nh4K_c:1 |
# protein:  Clo1313_0185 	cofacs: | mg2_c:1 |
# protein:  Clo1313_0186 	cofacs: | zn2_c:1 |
# protein:  Clo1313_0217 	cofacs: | mg2_c:1 |
# protein:  Clo1313_0218 	cofacs: | mg2_c:2 |
# protein:  Clo1313_0236 	cofacs: | metalIon_c:1 |
# protein:  Clo1313_0275 	cofacs: | fmn_c:1 |
# protein:  Clo1313_0288 	cofacs: | pydx5p_c:1 |
# protein:  Clo1313_0305 	cofacs: | mg2_c:1 |
# protein:  Clo1313_0383 	cofacs: | 4fe4s_c:1 |
# protein:  Clo1313_0388 	cofacs: | pydx5p_c:1 |
# protein:  Clo1313_0400 	cofacs: | CaZn_c:1 |
# protein:  Clo1313_0415 	cofacs: | mn2_c:1 |
# protein:  Clo1313_0423 	cofacs: | zn2_c:1 |
# protein:  Clo1313_0424 	cofacs: | pydx5p_c:1 |
# protein:  Clo1313_0497 	cofacs: | divalentCation_c:1 |
# protein:  Clo1313_0542 	cofacs: | fad_c:1 |
# protein:  Clo1313_0554 	cofacs: | 4fe4s_c:1 |
# protein:  Clo1313_0570 	cofacs: | 4fe4s_c:1 |
# protein:  Clo1313_0571 	cofacs: | ni2_c:1 |
# protein:  Clo1313_0579 	cofacs: | pydx5p_c:1 |
# protein:  Clo1313_0626 	cofacs: | 4fe4s_c:1 |
# protein:  Clo1313_0652 	cofacs: | pydx5p_c:1 |
# protein:  Clo1313_0657 	cofacs: | zn2_c:1 |
# protein:  Clo1313_0658 	cofacs: | mg2_c:1,amet_c:1,4fe4s_c:1 |
# protein:  Clo1313_0669 	cofacs: | zn2_c:1 |
# protein:  Clo1313_0673 	cofacs: | 4fe4s_c:3 |
# protein:  Clo1313_0703 	cofacs: | mg2_c:1 |
# protein:  Clo1313_0709 	cofacs: | 4fe4s_c:1 |
# protein:  Clo1313_0735 	cofacs: | 4fe4s_c:1 |
# protein:  Clo1313_0749 	cofacs: | zn2_c:1 |
# protein:  Clo1313_0823 	cofacs: | mg2_c:1 |
# protein:  Clo1313_0836 	cofacs: | pydx5p_c:1 |
# protein:  Clo1313_0859 	cofacs: | mg2_c:1 |
# protein:  Clo1313_0864 	cofacs: | mg2_c:1 |
# protein:  Clo1313_0867 	cofacs: | pydx5p_c:1 |
# protein:  Clo1313_0912 	cofacs: | 4fe4s_c:1 |
# protein:  Clo1313_0943 	cofacs: | fmn_c:1,mg2_c:1 |
# protein:  Clo1313_0948 	cofacs: | 4fe4s_c:1 |
# protein:  Clo1313_0949 	cofacs: | mg2_c:1 |
# protein:  Clo1313_0962 	cofacs: | mg2_c:1 |
# protein:  Clo1313_0982 	cofacs: | mg2_c:1 |
# protein:  Clo1313_0993 	cofacs: | mg2_c:1 |
# protein:  Clo1313_0997 	cofacs: | mg2_c:1 |
# protein:  Clo1313_1009 	cofacs: | mg2_c:1 |
# protein:  Clo1313_1029 	cofacs: | zn2_c:1 |
# protein:  Clo1313_1046 	cofacs: | pydx5p_c:1 |
# protein:  Clo1313_1057 	cofacs: | nad_c:1 |
# protein:  Clo1313_1094 	cofacs: | 4fe4s_c:1 |
# protein:  Clo1313_1098 	cofacs: | mg2_c:1 |
# protein:  Clo1313_1119 	cofacs: | 4fe4s_c:1 |
# protein:  Clo1313_1145 	cofacs: | zn2_c:1 |
# protein:  Clo1313_1150 	cofacs: | pydx5p_c:1 |
# protein:  Clo1313_1155 	cofacs: | pydx5p_c:1 |
# protein:  Clo1313_1186 	cofacs: | MgMn_c:1 |
# protein:  Clo1313_1214 	cofacs: | mg2_c:2 |
# protein:  Clo1313_1216 	cofacs: | divalentCation_c:1 |
# protein:  Clo1313_1218 	cofacs: | 4fe4s_c:1 |
# protein:  Clo1313_1240 	cofacs: | mg2_c:1 |
# protein:  Clo1313_1265 	cofacs: | zn2_c:2 |
# protein:  Clo1313_1268 	cofacs: | MgMn_c:4 |
# protein:  Clo1313_1269 	cofacs: | fad_c:1,2fe2s_c:2 |
# protein:  Clo1313_1270 	cofacs: | fmn_c:1 |
# protein:  Clo1313_1287 	cofacs: | 4fe4s_c:1 |
# protein:  Clo1313_1289 	cofacs: | divalentCation_c:1 |
# protein:  Clo1313_1312 	cofacs: | 4fe4s_c:1 |
# protein:  Clo1313_1316 	cofacs: | mg2_c:1 |
# protein:  Clo1313_1318 	cofacs: | pyr_c:1 |
# protein:  Clo1313_1346 	cofacs: | mg2_c:2 |
# protein:  Clo1313_1353 	cofacs: | 4fe4s_c:1 |
# protein:  Clo1313_1364 	cofacs: | pydx5p_c:1 |
# protein:  Clo1313_1393 	cofacs: | mg2_c:1,thmpp_c:1 |
# protein:  Clo1313_1396 	cofacs: | ca2_c:1 |
# protein:  Clo1313_1429 	cofacs: | pydx5p_c:1 |
# protein:  Clo1313_1434 	cofacs: | zn2_c:1 |
# protein:  Clo1313_1435 	cofacs: | CoZn_c:1 |
# protein:  Clo1313_1447 	cofacs: | mg2_c:1 |
# protein:  Clo1313_1467 	cofacs: | pydx5p_c:1 |
# protein:  Clo1313_1486 	cofacs: | mn2_c:1 |
# protein:  Clo1313_1492 	cofacs: | mg2_c:1 |
# protein:  Clo1313_1503 	cofacs: | pydx5p_c:1 |
# protein:  Clo1313_1508 	cofacs: | mg2_c:1 |
# protein:  Clo1313_1510 	cofacs: | 4fe4s_c:1 |
# protein:  Clo1313_1529 	cofacs: | metalIon_c:1 |
# protein:  Clo1313_1546 	cofacs: | mn2_c:1 |
# protein:  Clo1313_1571 	cofacs: | 2fe2s_c:1,4fe4s_c:1 |
# protein:  Clo1313_1581 	cofacs: | zn2_c:1 |
# protein:  Clo1313_1619 	cofacs: | pydx5p_c:1 |
# protein:  Clo1313_1628 	cofacs: | mg2_c:1 |
# protein:  Clo1313_1657 	cofacs: | pydx5p_c:1 |
# protein:  Clo1313_1661 	cofacs: | metalIon_c:1 |
# protein:  Clo1313_1662 	cofacs: | zn2_c:1 |
# protein:  Clo1313_1694 	cofacs: | ca2_c:1 |
# protein:  Clo1313_1704 	cofacs: | 4fe4s_c:1 |
# protein:  Clo1313_1791 	cofacs: | 4fe4s_c:1 |
# protein:  Clo1313_1792 	cofacs: | fmn_c:1,4fe4s_c:1 |
# protein:  Clo1313_1793 	cofacs: | 2fe2s_c:1  |
# protein:  Clo1313_1814 	cofacs: | 4fe4s_c:1 |
# protein:  Clo1313_1827 	cofacs: | fe2_c:1 |
# protein:  Clo1313_1833 	cofacs: | zn2_c:1 |
# protein:  Clo1313_1848 	cofacs: | fad_c:1,2fe2s_c:1 |
# protein:  Clo1313_1849 	cofacs: | 4fe4s_c:1 |
# protein:  Clo1313_1858 	cofacs: | pydx5p_c:1 |
# protein:  Clo1313_1875 	cofacs: | zn2_c:2 |
# protein:  Clo1313_1876 	cofacs: | mg2_c:1 |
# protein:  Clo1313_1879 	cofacs: | divalentCation_c:2 |
# protein:  Clo1313_1881 	cofacs: | 4fe4s_c:1 |
# protein:  Clo1313_1882 	cofacs: | fmn_c:1,4fe4s_c:1 |
# protein:  Clo1313_1885 	cofacs: | 2fe2s_c:1  |
# protein:  Clo1313_1931 	cofacs: | pydx5p_c:1 |
# protein:  Clo1313_1944 	cofacs: | MgMn_c:1 |
# protein:  Clo1313_1964 	cofacs: | pydx5p_c:1 |
# protein:  Clo1313_1997 	cofacs: | 4fe4s_c:1 |
# protein:  Clo1313_2017 	cofacs: | mg2_c:2 |
# protein:  Clo1313_2018 	cofacs: | mg2_c:2 |
# protein:  Clo1313_2033 	cofacs: | fad_c:1 |
# protein:  Clo1313_2044 	cofacs: | mg2_c:1 |
# protein:  Clo1313_2059 	cofacs: | mn2_c:1 |
# protein:  Clo1313_2077 	cofacs: | 4fe4s_c:1 |
# protein:  Clo1313_2090 	cofacs: | mg2_c:1 |
# protein:  Clo1313_2124 	cofacs: | mg2_c:1 |
# protein:  Clo1313_2125 	cofacs: | MgMn_c:1 |
# protein:  Clo1313_2127 	cofacs: | zn2_c:1 |
# protein:  Clo1313_2130 	cofacs: | fe2_c:1 |
# protein:  Clo1313_2132 	cofacs: | fad_c:1 |
# protein:  Clo1313_2144 	cofacs: | divalentCation_c:1 |
# protein:  Clo1313_2170 	cofacs: | mn2_c:1 |
# protein:  Clo1313_2198 	cofacs: | 4fe4s_c:1 |
# protein:  Clo1313_2207 	cofacs: | pydx5p_c:1 |
# protein:  Clo1313_2210 	cofacs: | pydx5p_c:1 |
# protein:  Clo1313_2212 	cofacs: | 4fe4s_c:1,2fe2s_c:1 |
# protein:  Clo1313_2278 	cofacs: | zn2_c:1 |
# protein:  Clo1313_2326 	cofacs: | pydx5p_c:1 |
# protein:  Clo1313_2334 	cofacs: | 4fe4s_c:1 |
# protein:  Clo1313_2335 	cofacs: | pydx5p_c:1 |
# protein:  Clo1313_2348 	cofacs: | zn2_c:1 |
# protein:  Clo1313_2490 	cofacs: | ni2_c:2 |
# protein:  Clo1313_2492 	cofacs: | ni2_c:1 |
# protein:  Clo1313_2531 	cofacs: | 4fe4s_c:1,2fe2s_c:1 |
# protein:  Clo1313_2532 	cofacs: | pydx5p_c:1 |
# protein:  Clo1313_2534 	cofacs: | pydx5p_c:1 |
# protein:  Clo1313_2558 	cofacs: | pydx5p_c:1 |
# protein:  Clo1313_2560 	cofacs: | MgMn_c:4 |
# protein:  Clo1313_2577 	cofacs: | pan4p_c:1 |
# protein:  Clo1313_2609 	cofacs: | MgMn_c:2 |
# protein:  Clo1313_2723 	cofacs: | zn2_c:1 |
# protein:  Clo1313_2743 	cofacs: | mn2_c:1 |
# protein:  Clo1313_2745 	cofacs: | mn2_c:1 |
# protein:  Clo1313_2754 	cofacs: | zn2_c:1 |
# protein:  Clo1313_2853 	cofacs: | divalentCation_c:1 |
# protein:  Clo1313_2882 	cofacs: | MgMn_c:1 |
# protein:  Clo1313_2924 	cofacs: | MgK_c:1 |
# protein:  Clo1313_2927 	cofacs: | mg2_c:1 |
# protein:  Clo1313_3018 	cofacs: | fad_c:1 |
# protein:  Clo1313_3019 	cofacs: | 4fe4s_c:1 |
# protein:  Clo1313_3022 	cofacs: | divalentCation_c:1 |
# protein:  Clo1313_1630 	cofacs: | 4fe4s_c:1 |

# %% [markdown]
# #### Save excel files

# %%
df_eqn.to_excel('./'+def_out+'/RBA_stoichiometry.xlsx', index=None)
