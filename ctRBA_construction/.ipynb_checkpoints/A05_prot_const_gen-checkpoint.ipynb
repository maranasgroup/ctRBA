# %%
import pandas as pd

cellulosome = pd.read_excel("prot_trans_const_file.xlsx", sheet_name = "Cellulosome Requirements")
metabolic = pd.read_excel("prot_trans_const_file.xlsx", sheet_name = "Metabolic Requirements")
# Out:
#    Cellulosome Protein  Measurement          MW  Flux (mmol/(gDW hr)
# 0         Clo1313_0627     0.000928  143.544675         2.585860e-06
# 1         Clo1313_2202     0.000002   67.333215         1.207099e-08
# 2         Clo1313_2189     0.000013   82.195395         6.228986e-08
# 3         Clo1313_2022     0.000004   37.896495         4.355273e-08
# 4         Clo1313_1960     0.001490   52.593460         1.133442e-05
# ..                 ...          ...         ...                  ...
# 60        Clo1313_0630     0.000392   48.331350         3.246200e-06
# 61        Clo1313_0628     0.001054  173.043880         2.436349e-06
# 62        Clo1313_1768     0.000052   29.122370         7.155780e-07
# 63        Clo1313_1487     0.000001  140.530330         3.306611e-09
# 64        Clo1313_1488     0.000072   28.542655         1.014623e-06
#
# [65 rows x 4 columns]

# %%
with open('prot_exp_flux_cell.txt', 'w') as file:
    line = f"/\n"
    file.write(line)
    for index, row in cellulosome.iterrows():
        line = f"'PROSYN-{row['Cellulosome Protein']}'\t{row['Flux (mmol/(gDW hr)']}\n"
        file.write(line)
    file.write("/")

# %%
with open('prot_exp_flux_met.txt', 'w') as file:
    line = f"/\n"
    file.write(line)
    for index, row in metabolic.iterrows():
        line = f"'PROSYN-{row['Metabolic Protein']}'\t{row['Flux (mmol/(gDW hr)']}\n"
        file.write(line)
    file.write("/")

# %%
with open('RBA_rxns_prosyn_cell.txt', 'w') as file:
    line = f"/\n"
    file.write(line)
    for index, row in cellulosome.iterrows():
        line = f"'PROSYN-{row['Cellulosome Protein']}'\n"
        file.write(line)
    file.write("/")

# %%
with open('RBA_rxns_prosyn_met.txt', 'w') as file:
    line = f"/\n"
    file.write(line)
    for index, row in metabolicppp.iterrows():
        line = f"'PROSYN-{row['Metabolic Protein']}'\n"
        file.write(line)
    file.write("/")
